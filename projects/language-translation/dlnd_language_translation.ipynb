# %% [markdown]
# # Language Translation
# In this project, you’re going to take a peek into the realm of neural network machine translation.  You’ll be training a sequence to sequence model on a dataset of English and French sentences that can translate new sentences from English to French.
# ## Get the Data
# Since translating the whole language of English to French will take lots of time to train, we have provided you with a small portion of the English corpus.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import helper
import problem_unittests as tests

source_path = 'data/small_vocab_en'
target_path = 'data/small_vocab_fr'
source_text = helper.load_data(source_path)
target_text = helper.load_data(target_path)

# %%
#target_text

# %% [markdown]
# ## Explore the Data
# Play around with view_sentence_range to view different parts of the data.

# %%
#view_sentence_range = (0, 10)

view_sentence_range = (31, 40)



"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np

print('Dataset Stats')
print('Roughly the number of unique words: {}'.format(len({word: None for word in source_text.split()})))

sentences = source_text.split('\n')
word_counts = [len(sentence.split()) for sentence in sentences]
print('Number of sentences: {}'.format(len(sentences)))
print('Average number of words in a sentence: {}'.format(np.average(word_counts)))

print()
print('English sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(source_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
print()
print('French sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(target_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
# Out:
# Dataset Stats
# Roughly the number of unique words: 227
# Number of sentences: 137861
# Average number of words in a sentence: 13.225277634719028
#
# English sentences 31 to 40:
# california is usually freezing during december , and it is busy in april .
# your most feared animal is that shark .
# paris is usually wet during august , and it is never dry in november .
# paris is usually beautiful during september , and it is usually snowy in november .
# the united states is never wet during january , but it is usually hot in october .
# we like oranges , mangoes , and grapes .
# they like pears , apples , and mangoes .
# she dislikes that little red truck .
# the grapefruit is my most loved fruit , but the banana is her most loved .
#
# French sentences 31 to 40:
# la californie est le gel habituellement en décembre , et il est occupé en avril .
# votre animal le plus redouté est que le requin .
# paris est généralement humide au mois d' août , et il est jamais sec en novembre .
# paris est généralement beau en septembre , et il est généralement enneigée en novembre .
# les états-unis est jamais humide en janvier , mais il est généralement chaud en octobre .
# nous aimons les oranges , les mangues et les raisins .
# ils aiment les poires , les pommes et les mangues .
# elle déteste ce petit camion rouge .
# le pamplemousse est mon fruit le plus cher , mais la banane est la plus aimée .

# %% [markdown]
# ## Implement Preprocessing Function
# ### Text to Word Ids
# As you did with other RNNs, you must turn the text into a number so the computer can understand it. In the function `text_to_ids()`, you'll turn `source_text` and `target_text` from words to ids.  However, you need to add the `<EOS>` word id at the end of each sentence from `target_text`.  This will help the neural network predict when the sentence should end.
#
# You can get the `<EOS>` word id by doing:
# ```python
# target_vocab_to_int['<EOS>']
# ```
# You can get other word ids using `source_vocab_to_int` and `target_vocab_to_int`.

# %%
def text_to_ids(source_text, target_text, source_vocab_to_int, target_vocab_to_int):
    """
    Convert source and target text to proper word ids
    :param source_text: String that contains all the source text.
    :param target_text: String that contains all the target text.
    :param source_vocab_to_int: Dictionary to go from the source words to an id
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: A tuple of lists (source_id_text, target_id_text)
    """
    # TODO: Implement Function
    
    source_sentences = source_text.split('\n')
    target_sentences = target_text.split('\n')

    #print(source_vocab_to_int)
    
    source_id_text = []
    for sentence in source_sentences:
        words = sentence.split()
        mysentence = []
        for word in words:
            mysentence.append(source_vocab_to_int.get(word,0)) # return 0 if not in the dd
            #mysentence.append(source_vocab_to_int[word])
            #print(source_vocab_to_int[word])
            #print(source_vocab_to_int.get(word,0))
        source_id_text.append(mysentence)
    
    target_id_text = []
    for sentence in target_sentences:
        words = sentence.split()
        mysentence = []
        for word in words:
            mysentence.append(target_vocab_to_int.get(word,0)) # return 0 is the word doesn't exit in the dd
        mysentence.append(target_vocab_to_int['<EOS>'])
        target_id_text.append(mysentence)
    
#     print(source_id_text[0])
#     print(target_id_text[0])

    return source_id_text, target_id_text

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_text_to_ids(text_to_ids)
# Out:
# Tests Passed

# %% [markdown]
# ### Preprocess all the data and save it
# Running the code cell below will preprocess all the data and save it to file.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
helper.preprocess_and_save_data(source_path, target_path, text_to_ids)

# %% [markdown]
# # Check Point
# This is your first checkpoint. If you ever decide to come back to this notebook or have to restart the notebook, you can start from here. The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np
import helper

(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()

# %% [markdown]
# ### Check the Version of TensorFlow and Access to GPU
# This will check to make sure you have the correct version of TensorFlow and access to a GPU

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
from distutils.version import LooseVersion
import warnings
import tensorflow as tf

# Check TensorFlow Version
assert LooseVersion(tf.__version__) in [LooseVersion('1.0.0'), LooseVersion('1.0.1')], 'This project requires TensorFlow version 1.0  You are using {}'.format(tf.__version__)
print('TensorFlow Version: {}'.format(tf.__version__))

# Check for a GPU
if not tf.test.gpu_device_name():
    warnings.warn('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# TensorFlow Version: 1.0.1
# Default GPU Device: /gpu:0

# %% [markdown]
# ## Build the Neural Network
# You'll build the components necessary to build a Sequence-to-Sequence model by implementing the following functions below:
# - `model_inputs`
# - `process_decoding_input`
# - `encoding_layer`
# - `decoding_layer_train`
# - `decoding_layer_infer`
# - `decoding_layer`
# - `seq2seq_model`
#
# ### Input
# Implement the `model_inputs()` function to create TF Placeholders for the Neural Network. It should create the following placeholders:
#
# - Input text placeholder named "input" using the TF Placeholder name parameter with rank 2.
# - Targets placeholder with rank 2.
# - Learning rate placeholder with rank 0.
# - Keep probability placeholder named "keep_prob" using the TF Placeholder name parameter with rank 0.
#
# Return the placeholders in the following the tuple (Input, Targets, Learing Rate, Keep Probability)

# %%
def model_inputs():
    """
    Create TF Placeholders for input, targets, and learning rate.
    :return: Tuple (input, targets, learning rate, keep probability)
    """
    # TODO: Implement Function
    inputs = tf.placeholder(dtype = tf.int32, 
                            shape=(None, None), name='input')
    
    targets = tf.placeholder(dtype = tf.int32, 
                            shape=(None, None), name='targets')
    
    learning_rate = tf.placeholder(dtype = tf.float32,
                                   name='learning_rate')
    
    keep_prob = tf.placeholder(dtype = tf.float32,
                                   name='keep_prob')
    
    
    return (inputs, targets, learning_rate, keep_prob)

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_inputs(model_inputs)
# Out:
# Tests Passed

# %% [markdown]
# ### Process Decoding Input
# Implement `process_decoding_input` using TensorFlow to remove the last word id from each batch in `target_data` and concat the GO ID to the beginning of each batch.

# %%
def process_decoding_input(target_data, target_vocab_to_int, batch_size):
    """
    Preprocess target data for decoding
    :param target_data: Target Placehoder
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param batch_size: Batch Size
    :return: Preprocessed target data
    """
    # TODO: Implement Function
    newbatch = tf.strided_slice(target_data, [0, 0], [batch_size, -1], [1, 1])
    newtarget = tf.concat([tf.fill([batch_size, 1], 
                                target_vocab_to_int['<GO>']), 
                                newbatch], 1)
    return newtarget

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_process_decoding_input(process_decoding_input)
# Out:
# Tests Passed

# %% [markdown]
# ### Encoding
# Implement `encoding_layer()` to create a Encoder RNN layer using [`tf.nn.dynamic_rnn()`](https://www.tensorflow.org/api_docs/python/tf/nn/dynamic_rnn).

# %%
def encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob):
    """
    Create encoding layer
    :param rnn_inputs: Inputs for the RNN
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param keep_prob: Dropout keep probability
    :return: RNN state
    """
    # TODO: Implement Function
    cell = tf.contrib.rnn.BasicLSTMCell(rnn_size) # lstm cell
    
    cell = tf.contrib.rnn.DropoutWrapper(cell, output_keep_prob = keep_prob)
    
    cell = tf.contrib.rnn.MultiRNNCell([cell] * num_layers)
    
    output, state = tf.nn.dynamic_rnn(cell, rnn_inputs, dtype=tf.float32)
    
    
    return state

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_encoding_layer(encoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### Decoding - Training
# Create training logits using [`tf.contrib.seq2seq.simple_decoder_fn_train()`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/simple_decoder_fn_train) and [`tf.contrib.seq2seq.dynamic_rnn_decoder()`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/dynamic_rnn_decoder).  Apply the `output_fn` to the [`tf.contrib.seq2seq.dynamic_rnn_decoder()`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/dynamic_rnn_decoder) outputs.

# %%
def decoding_layer_train(encoder_state, dec_cell, dec_embed_input, sequence_length, decoding_scope,
                         output_fn, keep_prob):
    """
    Create a decoding layer for training
    :param encoder_state: Encoder State
    :param dec_cell: Decoder RNN Cell
    :param dec_embed_input: Decoder embedded input
    :param sequence_length: Sequence Length
    :param decoding_scope: TenorFlow Variable Scope for decoding
    :param output_fn: Function to apply the output layer
    :param keep_prob: Dropout keep probability
    :return: Train Logits
    """
    # TODO: Implement Function
    decoder_fn = tf.contrib.seq2seq.simple_decoder_fn_train(encoder_state)
    
    outputs, state, context = tf.contrib.seq2seq.dynamic_rnn_decoder(dec_cell, 
                                                                     decoder_fn, 
                                                                     inputs = dec_embed_input,
                                                                     sequence_length=sequence_length,
                                                                     scope=decoding_scope)
    training_logits = output_fn(outputs)
    
    
    return training_logits

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_train(decoding_layer_train)
# Out:
# Tests Passed

# %% [markdown]
# ### Decoding - Inference
# Create inference logits using [`tf.contrib.seq2seq.simple_decoder_fn_inference()`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/simple_decoder_fn_inference) and [`tf.contrib.seq2seq.dynamic_rnn_decoder()`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/dynamic_rnn_decoder).

# %%
def decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id, end_of_sequence_id,
                         maximum_length, vocab_size, decoding_scope, output_fn, keep_prob):
    """
    Create a decoding layer for inference
    :param encoder_state: Encoder state
    :param dec_cell: Decoder RNN Cell
    :param dec_embeddings: Decoder embeddings
    :param start_of_sequence_id: GO ID
    :param end_of_sequence_id: EOS Id
    :param maximum_length: The maximum allowed time steps to decode
    :param vocab_size: Size of vocabulary
    :param decoding_scope: TensorFlow Variable Scope for decoding
    :param output_fn: Function to apply the output layer
    :param keep_prob: Dropout keep probability
    :return: Inference Logits
    """
    # TODO: Implement Function
    infer_fn = tf.contrib.seq2seq.simple_decoder_fn_inference(output_fn,
                                                              encoder_state,
                                                              dec_embeddings,
                                                              start_of_sequence_id, 
                                                              end_of_sequence_id,
                                                              maximum_length, 
                                                              num_decoder_symbols = vocab_size,
                                                              dtype = tf.int32)
    
    dp_cell = tf.contrib.rnn.DropoutWrapper(dec_cell, output_keep_prob = keep_prob)
    
    outputs, state, context = tf.contrib.seq2seq.dynamic_rnn_decoder(dp_cell, 
                                                                     infer_fn, 
                                                                     sequence_length=maximum_length,
                                                                     scope=decoding_scope)
    
    
    
    return outputs

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_infer(decoding_layer_infer)
# Out:
# Tests Passed

# %% [markdown]
# ### Build the Decoding Layer
# Implement `decoding_layer()` to create a Decoder RNN layer.
#
# - Create RNN cell for decoding using `rnn_size` and `num_layers`.
# - Create the output fuction using [`lambda`](https://docs.python.org/3/tutorial/controlflow.html#lambda-expressions) to transform it's input, logits, to class logits.
# - Use the your `decoding_layer_train(encoder_state, dec_cell, dec_embed_input, sequence_length, decoding_scope, output_fn, keep_prob)` function to get the training logits.
# - Use your `decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id, end_of_sequence_id, maximum_length, vocab_size, decoding_scope, output_fn, keep_prob)` function to get the inference logits.
#
# Note: You'll need to use [tf.variable_scope](https://www.tensorflow.org/api_docs/python/tf/variable_scope) to share variables between training and inference.

# %%
def decoding_layer(dec_embed_input, dec_embeddings, encoder_state, vocab_size, sequence_length, rnn_size,
                   num_layers, target_vocab_to_int, keep_prob):
    """
    Create decoding layer
    :param dec_embed_input: Decoder embedded input
    :param dec_embeddings: Decoder embeddings
    :param encoder_state: The encoded state
    :param vocab_size: Size of vocabulary
    :param sequence_length: Sequence Length
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param keep_prob: Dropout keep probability
    :return: Tuple of (Training Logits, Inference Logits)
    """
    # TODO: Implement Function
    start_symb, end_symb = target_vocab_to_int['<GO>'], target_vocab_to_int['<EOS>']
    
    lstm = tf.contrib.rnn.BasicLSTMCell(rnn_size)
    dropout = tf.contrib.rnn.DropoutWrapper(lstm, output_keep_prob=keep_prob)
    stack_lstm = tf.contrib.rnn.MultiRNNCell([dropout] * num_layers)
    
    output_fn = lambda x: tf.contrib.layers.fully_connected(x, vocab_size, activation_fn=None,scope = decoding_scope)
    
    with tf.variable_scope('decoding') as decoding_scope:
        training_logits = decoding_layer_train(encoder_state, 
                                               stack_lstm, 
                                               dec_embed_input,
                                               sequence_length, 
                                               decoding_scope, 
                                               output_fn, 
                                               keep_prob)
    
    
    with tf.variable_scope('decoding', reuse=True) as decoding_scope:
        infer_logits = decoding_layer_infer(encoder_state, 
                                            stack_lstm, 
                                            dec_embeddings,
                                            start_symb, 
                                            end_symb, 
                                            sequence_length, 
                                            vocab_size, 
                                            decoding_scope, 
                                            output_fn,
                                            keep_prob)
        
    
    
    return (training_logits, infer_logits)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer(decoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### Build the Neural Network
# Apply the functions you implemented above to:
#
# - Apply embedding to the input data for the encoder.
# - Encode the input using your `encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob)`.
# - Process target data using your `process_decoding_input(target_data, target_vocab_to_int, batch_size)` function.
# - Apply embedding to the target data for the decoder.
# - Decode the encoded input using your `decoding_layer(dec_embed_input, dec_embeddings, encoder_state, vocab_size, sequence_length, rnn_size, num_layers, target_vocab_to_int, keep_prob)`.

# %%
def seq2seq_model(input_data, target_data, keep_prob, batch_size, sequence_length, source_vocab_size, target_vocab_size,
                  enc_embedding_size, dec_embedding_size, rnn_size, num_layers, target_vocab_to_int):
    """
    Build the Sequence-to-Sequence part of the neural network
    :param input_data: Input placeholder
    :param target_data: Target placeholder
    :param keep_prob: Dropout keep probability placeholder
    :param batch_size: Batch Size
    :param sequence_length: Sequence Length
    :param source_vocab_size: Source vocabulary size
    :param target_vocab_size: Target vocabulary size
    :param enc_embedding_size: Decoder embedding size
    :param dec_embedding_size: Encoder embedding size
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: Tuple of (Training Logits, Inference Logits)
    """
    # TODO: Implement Function
    enc_embed = tf.contrib.layers.embed_sequence(input_data, source_vocab_size, enc_embedding_size)
    
    encode = encoding_layer(enc_embed, rnn_size, num_layers, keep_prob)
    
    dec_process = process_decoding_input(target_data, target_vocab_to_int, batch_size)
    
    dec_embed = tf.Variable(tf.random_uniform([target_vocab_size, dec_embedding_size]))
    
    dec_input = tf.nn.embedding_lookup(dec_embed, dec_process)
    
    train_logits, infer_logits = decoding_layer(dec_input, 
                                                       dec_embed, 
                                                       encode,
                                                       target_vocab_size, 
                                                       sequence_length, 
                                                       rnn_size, 
                                                       num_layers, 
                                                       target_vocab_to_int,
                                                       keep_prob)
    
    return (train_logits, infer_logits)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_seq2seq_model(seq2seq_model)
# Out:
# Tests Passed

# %% [markdown]
# ## Neural Network Training
# ### Hyperparameters
# Tune the following parameters:
#
# - Set `epochs` to the number of epochs.
# - Set `batch_size` to the batch size.
# - Set `rnn_size` to the size of the RNNs.
# - Set `num_layers` to the number of layers.
# - Set `encoding_embedding_size` to the size of the embedding for the encoder.
# - Set `decoding_embedding_size` to the size of the embedding for the decoder.
# - Set `learning_rate` to the learning rate.
# - Set `keep_probability` to the Dropout keep probability

# %%
# Number of Epochs
epochs = 4
# Batch Size
batch_size = 128
# RNN Size
rnn_size = 256
# Number of Layers
num_layers = 3
# Embedding Size
encoding_embedding_size = 128
decoding_embedding_size = 128
# Learning Rate
learning_rate = 0.001
# Dropout Keep Probability
keep_probability = 0.8

# %% [markdown]
# ### Build the Graph
# Build the graph using the neural network you implemented.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_path = 'checkpoints/dev'
(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()
max_source_sentence_length = max([len(sentence) for sentence in source_int_text])

train_graph = tf.Graph()
with train_graph.as_default():
    input_data, targets, lr, keep_prob = model_inputs()
    sequence_length = tf.placeholder_with_default(max_source_sentence_length, None, name='sequence_length')
    input_shape = tf.shape(input_data)
    
    train_logits, inference_logits = seq2seq_model(
        tf.reverse(input_data, [-1]), targets, keep_prob, batch_size, sequence_length, len(source_vocab_to_int), len(target_vocab_to_int),
        encoding_embedding_size, decoding_embedding_size, rnn_size, num_layers, target_vocab_to_int)

    tf.identity(inference_logits, 'logits')
    with tf.name_scope("optimization"):
        # Loss function
        cost = tf.contrib.seq2seq.sequence_loss(
            train_logits,
            targets,
            tf.ones([input_shape[0], sequence_length]))

        # Optimizer
        optimizer = tf.train.AdamOptimizer(lr)

        # Gradient Clipping
        gradients = optimizer.compute_gradients(cost)
        capped_gradients = [(tf.clip_by_value(grad, -1., 1.), var) for grad, var in gradients if grad is not None]
        train_op = optimizer.apply_gradients(capped_gradients)

# %% [markdown]
# ### Train
# Train the neural network on the preprocessed data. If you have a hard time getting a good loss, check the forms to see if anyone is having the same problem.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import time

def get_accuracy(target, logits):
    """
    Calculate accuracy
    """
    max_seq = max(target.shape[1], logits.shape[1])
    if max_seq - target.shape[1]:
        target = np.pad(
            target,
            [(0,0),(0,max_seq - target.shape[1])],
            'constant')
    if max_seq - logits.shape[1]:
        logits = np.pad(
            logits,
            [(0,0),(0,max_seq - logits.shape[1]), (0,0)],
            'constant')

    return np.mean(np.equal(target, np.argmax(logits, 2)))

train_source = source_int_text[batch_size:]
train_target = target_int_text[batch_size:]

valid_source = helper.pad_sentence_batch(source_int_text[:batch_size])
valid_target = helper.pad_sentence_batch(target_int_text[:batch_size])

with tf.Session(graph=train_graph) as sess:
    sess.run(tf.global_variables_initializer())

    for epoch_i in range(epochs):
        for batch_i, (source_batch, target_batch) in enumerate(
                helper.batch_data(train_source, train_target, batch_size)):
            start_time = time.time()
            
            _, loss = sess.run(
                [train_op, cost],
                {input_data: source_batch,
                 targets: target_batch,
                 lr: learning_rate,
                 sequence_length: target_batch.shape[1],
                 keep_prob: keep_probability})
            
            batch_train_logits = sess.run(
                inference_logits,
                {input_data: source_batch, keep_prob: 1.0})
            batch_valid_logits = sess.run(
                inference_logits,
                {input_data: valid_source, keep_prob: 1.0})
                
            train_acc = get_accuracy(target_batch, batch_train_logits)
            valid_acc = get_accuracy(np.array(valid_target), batch_valid_logits)
            end_time = time.time()
            print('Epoch {:>3} Batch {:>4}/{} - Train Accuracy: {:>6.3f}, Validation Accuracy: {:>6.3f}, Loss: {:>6.3f}'
                  .format(epoch_i, batch_i, len(source_int_text) // batch_size, train_acc, valid_acc, loss))

    # Save Model
    saver = tf.train.Saver()
    saver.save(sess, save_path)
    print('Model Trained and Saved')
# Out:
# Epoch   0 Batch    0/1077 - Train Accuracy:  0.295, Validation Accuracy:  0.305, Loss:  5.852
# Epoch   0 Batch    1/1077 - Train Accuracy:  0.221, Validation Accuracy:  0.305, Loss:  5.546
# Epoch   0 Batch    2/1077 - Train Accuracy:  0.206, Validation Accuracy:  0.305, Loss:  5.135
# Epoch   0 Batch    3/1077 - Train Accuracy:  0.239, Validation Accuracy:  0.305, Loss:  4.656
# Epoch   0 Batch    4/1077 - Train Accuracy:  0.237, Validation Accuracy:  0.319, Loss:  4.688
# Epoch   0 Batch    5/1077 - Train Accuracy:  0.291, Validation Accuracy:  0.332, Loss:  4.321
# Epoch   0 Batch    6/1077 - Train Accuracy:  0.279, Validation Accuracy:  0.337, Loss:  4.181
# Epoch   0 Batch    7/1077 - Train Accuracy:  0.262, Validation Accuracy:  0.337, Loss:  4.115
# Epoch   0 Batch    8/1077 - Train Accuracy:  0.269, Validation Accuracy:  0.337, Loss:  3.971
# Epoch   0 Batch    9/1077 - Train Accuracy:  0.274, Validation Accuracy:  0.337, Loss:  3.834
# Epoch   0 Batch   10/1077 - Train Accuracy:  0.240, Validation Accuracy:  0.337, Loss:  3.838
# Epoch   0 Batch   11/1077 - Train Accuracy:  0.303, Validation Accuracy:  0.346, Loss:  3.524
# Epoch   0 Batch   12/1077 - Train Accuracy:  0.298, Validation Accuracy:  0.369, Loss:  3.555
# Epoch   0 Batch   13/1077 - Train Accuracy:  0.344, Validation Accuracy:  0.369, Loss:  3.349
# Epoch   0 Batch   14/1077 - Train Accuracy:  0.331, Validation Accuracy:  0.372, Loss:  3.314
# Epoch   0 Batch   15/1077 - Train Accuracy:  0.304, Validation Accuracy:  0.365, Loss:  3.394
# Epoch   0 Batch   16/1077 - Train Accuracy:  0.320, Validation Accuracy:  0.363, Loss:  3.335
# Epoch   0 Batch   17/1077 - Train Accuracy:  0.321, Validation Accuracy:  0.366, Loss:  3.273
# Epoch   0 Batch   18/1077 - Train Accuracy:  0.306, Validation Accuracy:  0.368, Loss:  3.300
# Epoch   0 Batch   19/1077 - Train Accuracy:  0.333, Validation Accuracy:  0.376, Loss:  3.188
# Epoch   0 Batch   20/1077 - Train Accuracy:  0.312, Validation Accuracy:  0.376, Loss:  3.193
# Epoch   0 Batch   21/1077 - Train Accuracy:  0.311, Validation Accuracy:  0.388, Loss:  3.226
# Epoch   0 Batch   22/1077 - Train Accuracy:  0.331, Validation Accuracy:  0.395, Loss:  3.171
# Epoch   0 Batch   23/1077 - Train Accuracy:  0.342, Validation Accuracy:  0.400, Loss:  3.141
# Epoch   0 Batch   24/1077 - Train Accuracy:  0.346, Validation Accuracy:  0.405, Loss:  3.051
# Epoch   0 Batch   25/1077 - Train Accuracy:  0.350, Validation Accuracy:  0.409, Loss:  3.108
# Epoch   0 Batch   26/1077 - Train Accuracy:  0.330, Validation Accuracy:  0.398, Loss:  3.080
# Epoch   0 Batch   27/1077 - Train Accuracy:  0.398, Validation Accuracy:  0.416, Loss:  2.837
# Epoch   0 Batch   28/1077 - Train Accuracy:  0.375, Validation Accuracy:  0.417, Loss:  2.968
# Epoch   0 Batch   29/1077 - Train Accuracy:  0.379, Validation Accuracy:  0.431, Loss:  2.941
# Epoch   0 Batch   30/1077 - Train Accuracy:  0.376, Validation Accuracy:  0.445, Loss:  2.948
# Epoch   0 Batch   31/1077 - Train Accuracy:  0.368, Validation Accuracy:  0.435, Loss:  2.972
# Epoch   0 Batch   32/1077 - Train Accuracy:  0.420, Validation Accuracy:  0.434, Loss:  2.755
# Epoch   0 Batch   33/1077 - Train Accuracy:  0.403, Validation Accuracy:  0.425, Loss:  2.802
# Epoch   0 Batch   34/1077 - Train Accuracy:  0.364, Validation Accuracy:  0.429, Loss:  2.893
# Epoch   0 Batch   35/1077 - Train Accuracy:  0.357, Validation Accuracy:  0.417, Loss:  2.862
# Epoch   0 Batch   36/1077 - Train Accuracy:  0.389, Validation Accuracy:  0.443, Loss:  2.820
# Epoch   0 Batch   37/1077 - Train Accuracy:  0.399, Validation Accuracy:  0.454, Loss:  2.836
# Epoch   0 Batch   38/1077 - Train Accuracy:  0.344, Validation Accuracy:  0.432, Loss:  3.032
# Epoch   0 Batch   39/1077 - Train Accuracy:  0.379, Validation Accuracy:  0.446, Loss:  2.858
# Epoch   0 Batch   40/1077 - Train Accuracy:  0.388, Validation Accuracy:  0.441, Loss:  2.795
# Epoch   0 Batch   41/1077 - Train Accuracy:  0.420, Validation Accuracy:  0.454, Loss:  2.717
# Epoch   0 Batch   42/1077 - Train Accuracy:  0.410, Validation Accuracy:  0.468, Loss:  2.763
# Epoch   0 Batch   43/1077 - Train Accuracy:  0.402, Validation Accuracy:  0.468, Loss:  2.781
# Epoch   0 Batch   44/1077 - Train Accuracy:  0.376, Validation Accuracy:  0.473, Loss:  2.902
# Epoch   0 Batch   45/1077 - Train Accuracy:  0.389, Validation Accuracy:  0.460, Loss:  2.742
# Epoch   0 Batch   46/1077 - Train Accuracy:  0.394, Validation Accuracy:  0.468, Loss:  2.776
# Epoch   0 Batch   47/1077 - Train Accuracy:  0.427, Validation Accuracy:  0.477, Loss:  2.647
# Epoch   0 Batch   48/1077 - Train Accuracy:  0.420, Validation Accuracy:  0.471, Loss:  2.664
# Epoch   0 Batch   49/1077 - Train Accuracy:  0.414, Validation Accuracy:  0.461, Loss:  2.664
# Epoch   0 Batch   50/1077 - Train Accuracy:  0.403, Validation Accuracy:  0.458, Loss:  2.725
# Epoch   0 Batch   51/1077 - Train Accuracy:  0.434, Validation Accuracy:  0.463, Loss:  2.573
# Epoch   0 Batch   52/1077 - Train Accuracy:  0.410, Validation Accuracy:  0.469, Loss:  2.684
# Epoch   0 Batch   53/1077 - Train Accuracy:  0.420, Validation Accuracy:  0.473, Loss:  2.640
# Epoch   0 Batch   54/1077 - Train Accuracy:  0.399, Validation Accuracy:  0.477, Loss:  2.772
# Epoch   0 Batch   55/1077 - Train Accuracy:  0.436, Validation Accuracy:  0.471, Loss:  2.530
# Epoch   0 Batch   56/1077 - Train Accuracy:  0.430, Validation Accuracy:  0.464, Loss:  2.571
# Epoch   0 Batch   57/1077 - Train Accuracy:  0.489, Validation Accuracy:  0.484, Loss:  2.341
# Epoch   0 Batch   58/1077 - Train Accuracy:  0.434, Validation Accuracy:  0.480, Loss:  2.577
# Epoch   0 Batch   59/1077 - Train Accuracy:  0.375, Validation Accuracy:  0.468, Loss:  2.697
# Epoch   0 Batch   60/1077 - Train Accuracy:  0.443, Validation Accuracy:  0.475, Loss:  2.504
# Epoch   0 Batch   61/1077 - Train Accuracy:  0.420, Validation Accuracy:  0.479, Loss:  2.542
# Epoch   0 Batch   62/1077 - Train Accuracy:  0.409, Validation Accuracy:  0.481, Loss:  2.677
# Epoch   0 Batch   63/1077 - Train Accuracy:  0.464, Validation Accuracy:  0.490, Loss:  2.394
# Epoch   0 Batch   64/1077 - Train Accuracy:  0.419, Validation Accuracy:  0.476, Loss:  2.533
# Epoch   0 Batch   65/1077 - Train Accuracy:  0.396, Validation Accuracy:  0.474, Loss:  2.639
# Epoch   0 Batch   66/1077 - Train Accuracy:  0.419, Validation Accuracy:  0.471, Loss:  2.505
# Epoch   0 Batch   67/1077 - Train Accuracy:  0.455, Validation Accuracy:  0.486, Loss:  2.405
# Epoch   0 Batch   68/1077 - Train Accuracy:  0.422, Validation Accuracy:  0.487, Loss:  2.599
# Epoch   0 Batch   69/1077 - Train Accuracy:  0.436, Validation Accuracy:  0.465, Loss:  2.447
# Epoch   0 Batch   70/1077 - Train Accuracy:  0.414, Validation Accuracy:  0.494, Loss:  2.577
# Epoch   0 Batch   71/1077 - Train Accuracy:  0.422, Validation Accuracy:  0.496, Loss:  2.437
# Epoch   0 Batch   72/1077 - Train Accuracy:  0.424, Validation Accuracy:  0.463, Loss:  2.470
# Epoch   0 Batch   73/1077 - Train Accuracy:  0.401, Validation Accuracy:  0.452, Loss:  2.478
# Epoch   0 Batch   74/1077 - Train Accuracy:  0.456, Validation Accuracy:  0.506, Loss:  2.352
# Epoch   0 Batch   75/1077 - Train Accuracy:  0.466, Validation Accuracy:  0.504, Loss:  2.344
# Epoch   0 Batch   76/1077 - Train Accuracy:  0.431, Validation Accuracy:  0.472, Loss:  2.422
# Epoch   0 Batch   77/1077 - Train Accuracy:  0.397, Validation Accuracy:  0.446, Loss:  2.459
# Epoch   0 Batch   78/1077 - Train Accuracy:  0.415, Validation Accuracy:  0.508, Loss:  2.583
# Epoch   0 Batch   79/1077 - Train Accuracy:  0.421, Validation Accuracy:  0.497, Loss:  2.462
# Epoch   0 Batch   80/1077 - Train Accuracy:  0.436, Validation Accuracy:  0.490, Loss:  2.435
# Epoch   0 Batch   81/1077 - Train Accuracy:  0.421, Validation Accuracy:  0.456, Loss:  2.373
# Epoch   0 Batch   82/1077 - Train Accuracy:  0.496, Validation Accuracy:  0.493, Loss:  2.216
# Epoch   0 Batch   83/1077 - Train Accuracy:  0.430, Validation Accuracy:  0.506, Loss:  2.486
# Epoch   0 Batch   84/1077 - Train Accuracy:  0.449, Validation Accuracy:  0.495, Loss:  2.376
# Epoch   0 Batch   85/1077 - Train Accuracy:  0.446, Validation Accuracy:  0.465, Loss:  2.251
# Epoch   0 Batch   86/1077 - Train Accuracy:  0.445, Validation Accuracy:  0.494, Loss:  2.407
# Epoch   0 Batch   87/1077 - Train Accuracy:  0.452, Validation Accuracy:  0.506, Loss:  2.358
# Epoch   0 Batch   88/1077 - Train Accuracy:  0.463, Validation Accuracy:  0.504, Loss:  2.341
# Epoch   0 Batch   89/1077 - Train Accuracy:  0.441, Validation Accuracy:  0.488, Loss:  2.364
# Epoch   0 Batch   90/1077 - Train Accuracy:  0.436, Validation Accuracy:  0.495, Loss:  2.451
# Epoch   0 Batch   91/1077 - Train Accuracy:  0.499, Validation Accuracy:  0.505, Loss:  2.119
# Epoch   0 Batch   92/1077 - Train Accuracy:  0.459, Validation Accuracy:  0.497, Loss:  2.326
# Epoch   0 Batch   93/1077 - Train Accuracy:  0.428, Validation Accuracy:  0.479, Loss:  2.363
# Epoch   0 Batch   94/1077 - Train Accuracy:  0.465, Validation Accuracy:  0.507, Loss:  2.276
# Epoch   0 Batch   95/1077 - Train Accuracy:  0.480, Validation Accuracy:  0.510, Loss:  2.241
# Epoch   0 Batch   96/1077 - Train Accuracy:  0.434, Validation Accuracy:  0.468, Loss:  2.279
# Epoch   0 Batch   97/1077 - Train Accuracy:  0.461, Validation Accuracy:  0.489, Loss:  2.289
# Epoch   0 Batch   98/1077 - Train Accuracy:  0.482, Validation Accuracy:  0.506, Loss:  2.178
# Epoch   0 Batch   99/1077 - Train Accuracy:  0.409, Validation Accuracy:  0.475, Loss:  2.416
# Epoch   0 Batch  100/1077 - Train Accuracy:  0.443, Validation Accuracy:  0.490, Loss:  2.315
# Epoch   0 Batch  101/1077 - Train Accuracy:  0.464, Validation Accuracy:  0.514, Loss:  2.242
# Epoch   0 Batch  102/1077 - Train Accuracy:  0.462, Validation Accuracy:  0.478, Loss:  2.204
# Epoch   0 Batch  103/1077 - Train Accuracy:  0.409, Validation Accuracy:  0.499, Loss:  2.415
# Epoch   0 Batch  104/1077 - Train Accuracy:  0.370, Validation Accuracy:  0.482, Loss:  2.444
# Epoch   0 Batch  105/1077 - Train Accuracy:  0.465, Validation Accuracy:  0.509, Loss:  2.220
# Epoch   0 Batch  106/1077 - Train Accuracy:  0.458, Validation Accuracy:  0.508, Loss:  2.334
# Epoch   0 Batch  107/1077 - Train Accuracy:  0.438, Validation Accuracy:  0.453, Loss:  2.110
# Epoch   0 Batch  108/1077 - Train Accuracy:  0.489, Validation Accuracy:  0.504, Loss:  2.104
# Epoch   0 Batch  109/1077 - Train Accuracy:  0.468, Validation Accuracy:  0.517, Loss:  2.231
# Epoch   0 Batch  110/1077 - Train Accuracy:  0.458, Validation Accuracy:  0.485, Loss:  2.124
# Epoch   0 Batch  111/1077 - Train Accuracy:  0.451, Validation Accuracy:  0.507, Loss:  2.251
# Epoch   0 Batch  112/1077 - Train Accuracy:  0.457, Validation Accuracy:  0.518, Loss:  2.204
# Epoch   0 Batch  113/1077 - Train Accuracy:  0.446, Validation Accuracy:  0.500, Loss:  2.232
# Epoch   0 Batch  114/1077 - Train Accuracy:  0.436, Validation Accuracy:  0.471, Loss:  2.196
# Epoch   0 Batch  115/1077 - Train Accuracy:  0.430, Validation Accuracy:  0.507, Loss:  2.368
# Epoch   0 Batch  116/1077 - Train Accuracy:  0.393, Validation Accuracy:  0.464, Loss:  2.254
# Epoch   0 Batch  117/1077 - Train Accuracy:  0.421, Validation Accuracy:  0.519, Loss:  2.374
# Epoch   0 Batch  118/1077 - Train Accuracy:  0.391, Validation Accuracy:  0.485, Loss:  2.278
# Epoch   0 Batch  119/1077 - Train Accuracy:  0.450, Validation Accuracy:  0.504, Loss:  2.253
# Epoch   0 Batch  120/1077 - Train Accuracy:  0.431, Validation Accuracy:  0.485, Loss:  2.154
# Epoch   0 Batch  121/1077 - Train Accuracy:  0.439, Validation Accuracy:  0.491, Loss:  2.205
# Epoch   0 Batch  122/1077 - Train Accuracy:  0.442, Validation Accuracy:  0.498, Loss:  2.186
# Epoch   0 Batch  123/1077 - Train Accuracy:  0.450, Validation Accuracy:  0.478, Loss:  2.067
# Epoch   0 Batch  124/1077 - Train Accuracy:  0.446, Validation Accuracy:  0.495, Loss:  2.166
# Epoch   0 Batch  125/1077 - Train Accuracy:  0.458, Validation Accuracy:  0.500, Loss:  2.133
# Epoch   0 Batch  126/1077 - Train Accuracy:  0.451, Validation Accuracy:  0.497, Loss:  2.075
# Epoch   0 Batch  127/1077 - Train Accuracy:  0.456, Validation Accuracy:  0.508, Loss:  2.103
# Epoch   0 Batch  128/1077 - Train Accuracy:  0.491, Validation Accuracy:  0.502, Loss:  1.998
# Epoch   0 Batch  129/1077 - Train Accuracy:  0.463, Validation Accuracy:  0.510, Loss:  2.126
# Epoch   0 Batch  130/1077 - Train Accuracy:  0.463, Validation Accuracy:  0.509, Loss:  1.970
# Epoch   0 Batch  131/1077 - Train Accuracy:  0.443, Validation Accuracy:  0.501, Loss:  2.137
# Epoch   0 Batch  132/1077 - Train Accuracy:  0.446, Validation Accuracy:  0.514, Loss:  2.163
# Epoch   0 Batch  133/1077 - Train Accuracy:  0.435, Validation Accuracy:  0.508, Loss:  2.078
# Epoch   0 Batch  134/1077 - Train Accuracy:  0.458, Validation Accuracy:  0.522, Loss:  2.011
# Epoch   0 Batch  135/1077 - Train Accuracy:  0.461, Validation Accuracy:  0.522, Loss:  2.097
# Epoch   0 Batch  136/1077 - Train Accuracy:  0.474, Validation Accuracy:  0.520, Loss:  2.039
# Epoch   0 Batch  137/1077 - Train Accuracy:  0.494, Validation Accuracy:  0.517, Loss:  1.907
# Epoch   0 Batch  138/1077 - Train Accuracy:  0.464, Validation Accuracy:  0.525, Loss:  2.001
# Epoch   0 Batch  139/1077 - Train Accuracy:  0.461, Validation Accuracy:  0.518, Loss:  2.009
# Epoch   0 Batch  140/1077 - Train Accuracy:  0.412, Validation Accuracy:  0.513, Loss:  2.176
# Epoch   0 Batch  141/1077 - Train Accuracy:  0.464, Validation Accuracy:  0.524, Loss:  2.117
# Epoch   0 Batch  142/1077 - Train Accuracy:  0.504, Validation Accuracy:  0.516, Loss:  1.886
# Epoch   0 Batch  143/1077 - Train Accuracy:  0.477, Validation Accuracy:  0.510, Loss:  1.982
# Epoch   0 Batch  144/1077 - Train Accuracy:  0.436, Validation Accuracy:  0.517, Loss:  2.108
# Epoch   0 Batch  145/1077 - Train Accuracy:  0.501, Validation Accuracy:  0.513, Loss:  1.926
# Epoch   0 Batch  146/1077 - Train Accuracy:  0.490, Validation Accuracy:  0.517, Loss:  1.957
# Epoch   0 Batch  147/1077 - Train Accuracy:  0.444, Validation Accuracy:  0.514, Loss:  2.024
# Epoch   0 Batch  148/1077 - Train Accuracy:  0.489, Validation Accuracy:  0.527, Loss:  1.995
# Epoch   0 Batch  149/1077 - Train Accuracy:  0.454, Validation Accuracy:  0.527, Loss:  2.049
# Epoch   0 Batch  150/1077 - Train Accuracy:  0.497, Validation Accuracy:  0.521, Loss:  1.886
# Epoch   0 Batch  151/1077 - Train Accuracy:  0.480, Validation Accuracy:  0.514, Loss:  1.910
# Epoch   0 Batch  152/1077 - Train Accuracy:  0.482, Validation Accuracy:  0.514, Loss:  1.974
# Epoch   0 Batch  153/1077 - Train Accuracy:  0.452, Validation Accuracy:  0.518, Loss:  2.066
# Epoch   0 Batch  154/1077 - Train Accuracy:  0.423, Validation Accuracy:  0.500, Loss:  2.087
# Epoch   0 Batch  155/1077 - Train Accuracy:  0.477, Validation Accuracy:  0.522, Loss:  1.979
# Epoch   0 Batch  156/1077 - Train Accuracy:  0.452, Validation Accuracy:  0.528, Loss:  1.973
# Epoch   0 Batch  157/1077 - Train Accuracy:  0.471, Validation Accuracy:  0.523, Loss:  1.967
# Epoch   0 Batch  158/1077 - Train Accuracy:  0.485, Validation Accuracy:  0.522, Loss:  1.949
# Epoch   0 Batch  159/1077 - Train Accuracy:  0.489, Validation Accuracy:  0.525, Loss:  1.860
# Epoch   0 Batch  160/1077 - Train Accuracy:  0.466, Validation Accuracy:  0.506, Loss:  1.937
# Epoch   0 Batch  161/1077 - Train Accuracy:  0.466, Validation Accuracy:  0.532, Loss:  1.968
# Epoch   0 Batch  162/1077 - Train Accuracy:  0.475, Validation Accuracy:  0.518, Loss:  1.942
# Epoch   0 Batch  163/1077 - Train Accuracy:  0.438, Validation Accuracy:  0.512, Loss:  2.043
# Epoch   0 Batch  164/1077 - Train Accuracy:  0.465, Validation Accuracy:  0.510, Loss:  1.978
# Epoch   0 Batch  165/1077 - Train Accuracy:  0.434, Validation Accuracy:  0.509, Loss:  1.907
# Epoch   0 Batch  166/1077 - Train Accuracy:  0.481, Validation Accuracy:  0.488, Loss:  1.862
# Epoch   0 Batch  167/1077 - Train Accuracy:  0.429, Validation Accuracy:  0.489, Loss:  1.973
# Epoch   0 Batch  168/1077 - Train Accuracy:  0.440, Validation Accuracy:  0.511, Loss:  1.995
# Epoch   0 Batch  169/1077 - Train Accuracy:  0.499, Validation Accuracy:  0.509, Loss:  1.790
# Epoch   0 Batch  170/1077 - Train Accuracy:  0.427, Validation Accuracy:  0.502, Loss:  1.948
# Epoch   0 Batch  171/1077 - Train Accuracy:  0.478, Validation Accuracy:  0.506, Loss:  1.824
# Epoch   0 Batch  172/1077 - Train Accuracy:  0.480, Validation Accuracy:  0.512, Loss:  1.812
# Epoch   0 Batch  173/1077 - Train Accuracy:  0.417, Validation Accuracy:  0.513, Loss:  2.044
# Epoch   0 Batch  174/1077 - Train Accuracy:  0.470, Validation Accuracy:  0.501, Loss:  1.864
# Epoch   0 Batch  175/1077 - Train Accuracy:  0.481, Validation Accuracy:  0.516, Loss:  1.825
# Epoch   0 Batch  176/1077 - Train Accuracy:  0.445, Validation Accuracy:  0.509, Loss:  1.859
# Epoch   0 Batch  177/1077 - Train Accuracy:  0.433, Validation Accuracy:  0.510, Loss:  1.967
# Epoch   0 Batch  178/1077 - Train Accuracy:  0.480, Validation Accuracy:  0.532, Loss:  1.890
# Epoch   0 Batch  179/1077 - Train Accuracy:  0.460, Validation Accuracy:  0.525, Loss:  1.925
# Epoch   0 Batch  180/1077 - Train Accuracy:  0.443, Validation Accuracy:  0.505, Loss:  1.873
# Epoch   0 Batch  181/1077 - Train Accuracy:  0.451, Validation Accuracy:  0.494, Loss:  1.855
# Epoch   0 Batch  182/1077 - Train Accuracy:  0.474, Validation Accuracy:  0.520, Loss:  1.827
# Epoch   0 Batch  183/1077 - Train Accuracy:  0.408, Validation Accuracy:  0.485, Loss:  1.979
# Epoch   0 Batch  184/1077 - Train Accuracy:  0.424, Validation Accuracy:  0.484, Loss:  1.811
# Epoch   0 Batch  185/1077 - Train Accuracy:  0.432, Validation Accuracy:  0.498, Loss:  1.816
# Epoch   0 Batch  186/1077 - Train Accuracy:  0.453, Validation Accuracy:  0.491, Loss:  1.859
# Epoch   0 Batch  187/1077 - Train Accuracy:  0.430, Validation Accuracy:  0.492, Loss:  1.837
# Epoch   0 Batch  188/1077 - Train Accuracy:  0.449, Validation Accuracy:  0.489, Loss:  1.844
# Epoch   0 Batch  189/1077 - Train Accuracy:  0.435, Validation Accuracy:  0.501, Loss:  1.893
# Epoch   0 Batch  190/1077 - Train Accuracy:  0.486, Validation Accuracy:  0.502, Loss:  1.836
# Epoch   0 Batch  191/1077 - Train Accuracy:  0.511, Validation Accuracy:  0.512, Loss:  1.666
# Epoch   0 Batch  192/1077 - Train Accuracy:  0.480, Validation Accuracy:  0.510, Loss:  1.834
# Epoch   0 Batch  193/1077 - Train Accuracy:  0.500, Validation Accuracy:  0.512, Loss:  1.742
# Epoch   0 Batch  194/1077 - Train Accuracy:  0.490, Validation Accuracy:  0.510, Loss:  1.666
# Epoch   0 Batch  195/1077 - Train Accuracy:  0.454, Validation Accuracy:  0.517, Loss:  1.803
# Epoch   0 Batch  196/1077 - Train Accuracy:  0.477, Validation Accuracy:  0.514, Loss:  1.735
# Epoch   0 Batch  197/1077 - Train Accuracy:  0.478, Validation Accuracy:  0.515, Loss:  1.719
# Epoch   0 Batch  198/1077 - Train Accuracy:  0.516, Validation Accuracy:  0.513, Loss:  1.629
# Epoch   0 Batch  199/1077 - Train Accuracy:  0.467, Validation Accuracy:  0.511, Loss:  1.767
# Epoch   0 Batch  200/1077 - Train Accuracy:  0.433, Validation Accuracy:  0.503, Loss:  1.767
# Epoch   0 Batch  201/1077 - Train Accuracy:  0.470, Validation Accuracy:  0.508, Loss:  1.638
# Epoch   0 Batch  202/1077 - Train Accuracy:  0.476, Validation Accuracy:  0.512, Loss:  1.744
# Epoch   0 Batch  203/1077 - Train Accuracy:  0.472, Validation Accuracy:  0.501, Loss:  1.721
# Epoch   0 Batch  204/1077 - Train Accuracy:  0.469, Validation Accuracy:  0.506, Loss:  1.708
# Epoch   0 Batch  205/1077 - Train Accuracy:  0.468, Validation Accuracy:  0.499, Loss:  1.803
# Epoch   0 Batch  206/1077 - Train Accuracy:  0.464, Validation Accuracy:  0.496, Loss:  1.739
# Epoch   0 Batch  207/1077 - Train Accuracy:  0.439, Validation Accuracy:  0.500, Loss:  1.744
# Epoch   0 Batch  208/1077 - Train Accuracy:  0.467, Validation Accuracy:  0.490, Loss:  1.693
# Epoch   0 Batch  209/1077 - Train Accuracy:  0.469, Validation Accuracy:  0.499, Loss:  1.575
# Epoch   0 Batch  210/1077 - Train Accuracy:  0.471, Validation Accuracy:  0.497, Loss:  1.707
# Epoch   0 Batch  211/1077 - Train Accuracy:  0.439, Validation Accuracy:  0.489, Loss:  1.674
# Epoch   0 Batch  212/1077 - Train Accuracy:  0.495, Validation Accuracy:  0.489, Loss:  1.574
# Epoch   0 Batch  213/1077 - Train Accuracy:  0.463, Validation Accuracy:  0.492, Loss:  1.610
# Epoch   0 Batch  214/1077 - Train Accuracy:  0.444, Validation Accuracy:  0.496, Loss:  1.656
# Epoch   0 Batch  215/1077 - Train Accuracy:  0.439, Validation Accuracy:  0.498, Loss:  1.679
# Epoch   0 Batch  216/1077 - Train Accuracy:  0.438, Validation Accuracy:  0.499, Loss:  1.687
# Epoch   0 Batch  217/1077 - Train Accuracy:  0.494, Validation Accuracy:  0.506, Loss:  1.587
# Epoch   0 Batch  218/1077 - Train Accuracy:  0.435, Validation Accuracy:  0.488, Loss:  1.759
# Epoch   0 Batch  219/1077 - Train Accuracy:  0.472, Validation Accuracy:  0.490, Loss:  1.629
# Epoch   0 Batch  220/1077 - Train Accuracy:  0.456, Validation Accuracy:  0.507, Loss:  1.649
# Epoch   0 Batch  221/1077 - Train Accuracy:  0.466, Validation Accuracy:  0.501, Loss:  1.624
# Epoch   0 Batch  222/1077 - Train Accuracy:  0.438, Validation Accuracy:  0.505, Loss:  1.737
# Epoch   0 Batch  223/1077 - Train Accuracy:  0.469, Validation Accuracy:  0.493, Loss:  1.525
# Epoch   0 Batch  224/1077 - Train Accuracy:  0.468, Validation Accuracy:  0.496, Loss:  1.628
# Epoch   0 Batch  225/1077 - Train Accuracy:  0.446, Validation Accuracy:  0.492, Loss:  1.624
# Epoch   0 Batch  226/1077 - Train Accuracy:  0.456, Validation Accuracy:  0.500, Loss:  1.580
# Epoch   0 Batch  227/1077 - Train Accuracy:  0.444, Validation Accuracy:  0.488, Loss:  1.667
# Epoch   0 Batch  228/1077 - Train Accuracy:  0.486, Validation Accuracy:  0.487, Loss:  1.550
# Epoch   0 Batch  229/1077 - Train Accuracy:  0.486, Validation Accuracy:  0.494, Loss:  1.588
# Epoch   0 Batch  230/1077 - Train Accuracy:  0.489, Validation Accuracy:  0.495, Loss:  1.477
# Epoch   0 Batch  231/1077 - Train Accuracy:  0.491, Validation Accuracy:  0.517, Loss:  1.537
# Epoch   0 Batch  232/1077 - Train Accuracy:  0.454, Validation Accuracy:  0.519, Loss:  1.599
# Epoch   0 Batch  233/1077 - Train Accuracy:  0.462, Validation Accuracy:  0.526, Loss:  1.650
# Epoch   0 Batch  234/1077 - Train Accuracy:  0.494, Validation Accuracy:  0.525, Loss:  1.540
# Epoch   0 Batch  235/1077 - Train Accuracy:  0.524, Validation Accuracy:  0.528, Loss:  1.452
# Epoch   0 Batch  236/1077 - Train Accuracy:  0.468, Validation Accuracy:  0.511, Loss:  1.589
# Epoch   0 Batch  237/1077 - Train Accuracy:  0.496, Validation Accuracy:  0.527, Loss:  1.449
# Epoch   0 Batch  238/1077 - Train Accuracy:  0.493, Validation Accuracy:  0.522, Loss:  1.577
# Epoch   0 Batch  239/1077 - Train Accuracy:  0.480, Validation Accuracy:  0.514, Loss:  1.433
# Epoch   0 Batch  240/1077 - Train Accuracy:  0.482, Validation Accuracy:  0.525, Loss:  1.508
# Epoch   0 Batch  241/1077 - Train Accuracy:  0.505, Validation Accuracy:  0.510, Loss:  1.462
# Epoch   0 Batch  242/1077 - Train Accuracy:  0.456, Validation Accuracy:  0.513, Loss:  1.563
# Epoch   0 Batch  243/1077 - Train Accuracy:  0.420, Validation Accuracy:  0.515, Loss:  1.535
# Epoch   0 Batch  244/1077 - Train Accuracy:  0.502, Validation Accuracy:  0.515, Loss:  1.468
# Epoch   0 Batch  245/1077 - Train Accuracy:  0.468, Validation Accuracy:  0.517, Loss:  1.466
# Epoch   0 Batch  246/1077 - Train Accuracy:  0.449, Validation Accuracy:  0.511, Loss:  1.523
# Epoch   0 Batch  247/1077 - Train Accuracy:  0.501, Validation Accuracy:  0.510, Loss:  1.449
# Epoch   0 Batch  248/1077 - Train Accuracy:  0.487, Validation Accuracy:  0.512, Loss:  1.473
# Epoch   0 Batch  249/1077 - Train Accuracy:  0.456, Validation Accuracy:  0.495, Loss:  1.491
# Epoch   0 Batch  250/1077 - Train Accuracy:  0.501, Validation Accuracy:  0.523, Loss:  1.417
# Epoch   0 Batch  251/1077 - Train Accuracy:  0.487, Validation Accuracy:  0.507, Loss:  1.481
# Epoch   0 Batch  252/1077 - Train Accuracy:  0.482, Validation Accuracy:  0.511, Loss:  1.481
# Epoch   0 Batch  253/1077 - Train Accuracy:  0.502, Validation Accuracy:  0.515, Loss:  1.449
# Epoch   0 Batch  254/1077 - Train Accuracy:  0.482, Validation Accuracy:  0.504, Loss:  1.503
# Epoch   0 Batch  255/1077 - Train Accuracy:  0.460, Validation Accuracy:  0.502, Loss:  1.489
# Epoch   0 Batch  256/1077 - Train Accuracy:  0.434, Validation Accuracy:  0.506, Loss:  1.508
# Epoch   0 Batch  257/1077 - Train Accuracy:  0.492, Validation Accuracy:  0.486, Loss:  1.420
# Epoch   0 Batch  258/1077 - Train Accuracy:  0.479, Validation Accuracy:  0.499, Loss:  1.419
# Epoch   0 Batch  259/1077 - Train Accuracy:  0.470, Validation Accuracy:  0.514, Loss:  1.491
# Epoch   0 Batch  260/1077 - Train Accuracy:  0.484, Validation Accuracy:  0.471, Loss:  1.435
# Epoch   0 Batch  261/1077 - Train Accuracy:  0.484, Validation Accuracy:  0.492, Loss:  1.417
# Epoch   0 Batch  262/1077 - Train Accuracy:  0.462, Validation Accuracy:  0.506, Loss:  1.477
# Epoch   0 Batch  263/1077 - Train Accuracy:  0.470, Validation Accuracy:  0.495, Loss:  1.438
# Epoch   0 Batch  264/1077 - Train Accuracy:  0.452, Validation Accuracy:  0.502, Loss:  1.507
# Epoch   0 Batch  265/1077 - Train Accuracy:  0.473, Validation Accuracy:  0.511, Loss:  1.433
# Epoch   0 Batch  266/1077 - Train Accuracy:  0.472, Validation Accuracy:  0.491, Loss:  1.437
# Epoch   0 Batch  267/1077 - Train Accuracy:  0.472, Validation Accuracy:  0.493, Loss:  1.374
# Epoch   0 Batch  268/1077 - Train Accuracy:  0.500, Validation Accuracy:  0.536, Loss:  1.431
# Epoch   0 Batch  269/1077 - Train Accuracy:  0.477, Validation Accuracy:  0.537, Loss:  1.568
# Epoch   0 Batch  270/1077 - Train Accuracy:  0.442, Validation Accuracy:  0.517, Loss:  1.491
# Epoch   0 Batch  271/1077 - Train Accuracy:  0.459, Validation Accuracy:  0.518, Loss:  1.456
# Epoch   0 Batch  272/1077 - Train Accuracy:  0.493, Validation Accuracy:  0.529, Loss:  1.427
# Epoch   0 Batch  273/1077 - Train Accuracy:  0.464, Validation Accuracy:  0.510, Loss:  1.369
# Epoch   0 Batch  274/1077 - Train Accuracy:  0.480, Validation Accuracy:  0.527, Loss:  1.446
# Epoch   0 Batch  275/1077 - Train Accuracy:  0.474, Validation Accuracy:  0.517, Loss:  1.373
# Epoch   0 Batch  276/1077 - Train Accuracy:  0.448, Validation Accuracy:  0.502, Loss:  1.481
# Epoch   0 Batch  277/1077 - Train Accuracy:  0.484, Validation Accuracy:  0.516, Loss:  1.395
# Epoch   0 Batch  278/1077 - Train Accuracy:  0.478, Validation Accuracy:  0.511, Loss:  1.490
# Epoch   0 Batch  279/1077 - Train Accuracy:  0.428, Validation Accuracy:  0.485, Loss:  1.560
# Epoch   0 Batch  280/1077 - Train Accuracy:  0.457, Validation Accuracy:  0.481, Loss:  1.510
# Epoch   0 Batch  281/1077 - Train Accuracy:  0.432, Validation Accuracy:  0.479, Loss:  1.521
# Epoch   0 Batch  282/1077 - Train Accuracy:  0.456, Validation Accuracy:  0.521, Loss:  1.488
# Epoch   0 Batch  283/1077 - Train Accuracy:  0.496, Validation Accuracy:  0.522, Loss:  1.456
# Epoch   0 Batch  284/1077 - Train Accuracy:  0.451, Validation Accuracy:  0.519, Loss:  1.515
# Epoch   0 Batch  285/1077 - Train Accuracy:  0.524, Validation Accuracy:  0.495, Loss:  1.370
# Epoch   0 Batch  286/1077 - Train Accuracy:  0.483, Validation Accuracy:  0.482, Loss:  1.315
# Epoch   0 Batch  287/1077 - Train Accuracy:  0.473, Validation Accuracy:  0.497, Loss:  1.406
# Epoch   0 Batch  288/1077 - Train Accuracy:  0.429, Validation Accuracy:  0.503, Loss:  1.449
# Epoch   0 Batch  289/1077 - Train Accuracy:  0.477, Validation Accuracy:  0.486, Loss:  1.389
# Epoch   0 Batch  290/1077 - Train Accuracy:  0.496, Validation Accuracy:  0.525, Loss:  1.433
# Epoch   0 Batch  291/1077 - Train Accuracy:  0.490, Validation Accuracy:  0.509, Loss:  1.368
# Epoch   0 Batch  292/1077 - Train Accuracy:  0.507, Validation Accuracy:  0.527, Loss:  1.331
# Epoch   0 Batch  293/1077 - Train Accuracy:  0.463, Validation Accuracy:  0.532, Loss:  1.456
# Epoch   0 Batch  294/1077 - Train Accuracy:  0.531, Validation Accuracy:  0.523, Loss:  1.261
# Epoch   0 Batch  295/1077 - Train Accuracy:  0.458, Validation Accuracy:  0.520, Loss:  1.479
# Epoch   0 Batch  296/1077 - Train Accuracy:  0.495, Validation Accuracy:  0.518, Loss:  1.360
# Epoch   0 Batch  297/1077 - Train Accuracy:  0.448, Validation Accuracy:  0.509, Loss:  1.459
# Epoch   0 Batch  298/1077 - Train Accuracy:  0.484, Validation Accuracy:  0.505, Loss:  1.447
# Epoch   0 Batch  299/1077 - Train Accuracy:  0.476, Validation Accuracy:  0.500, Loss:  1.419
# Epoch   0 Batch  300/1077 - Train Accuracy:  0.441, Validation Accuracy:  0.507, Loss:  1.434
# Epoch   0 Batch  301/1077 - Train Accuracy:  0.473, Validation Accuracy:  0.515, Loss:  1.355
# Epoch   0 Batch  302/1077 - Train Accuracy:  0.505, Validation Accuracy:  0.525, Loss:  1.339
# Epoch   0 Batch  303/1077 - Train Accuracy:  0.454, Validation Accuracy:  0.512, Loss:  1.384
# Epoch   0 Batch  304/1077 - Train Accuracy:  0.490, Validation Accuracy:  0.529, Loss:  1.276
# Epoch   0 Batch  305/1077 - Train Accuracy:  0.488, Validation Accuracy:  0.535, Loss:  1.358
# Epoch   0 Batch  306/1077 - Train Accuracy:  0.459, Validation Accuracy:  0.506, Loss:  1.354
# Epoch   0 Batch  307/1077 - Train Accuracy:  0.431, Validation Accuracy:  0.518, Loss:  1.306
# Epoch   0 Batch  308/1077 - Train Accuracy:  0.479, Validation Accuracy:  0.537, Loss:  1.442
# Epoch   0 Batch  309/1077 - Train Accuracy:  0.497, Validation Accuracy:  0.542, Loss:  1.355
# Epoch   0 Batch  310/1077 - Train Accuracy:  0.412, Validation Accuracy:  0.499, Loss:  1.346
# Epoch   0 Batch  311/1077 - Train Accuracy:  0.513, Validation Accuracy:  0.509, Loss:  1.295
# Epoch   0 Batch  312/1077 - Train Accuracy:  0.480, Validation Accuracy:  0.527, Loss:  1.346
# Epoch   0 Batch  313/1077 - Train Accuracy:  0.457, Validation Accuracy:  0.532, Loss:  1.384
# Epoch   0 Batch  314/1077 - Train Accuracy:  0.482, Validation Accuracy:  0.506, Loss:  1.300
# Epoch   0 Batch  315/1077 - Train Accuracy:  0.500, Validation Accuracy:  0.522, Loss:  1.302
# Epoch   0 Batch  316/1077 - Train Accuracy:  0.505, Validation Accuracy:  0.526, Loss:  1.253
# Epoch   0 Batch  317/1077 - Train Accuracy:  0.492, Validation Accuracy:  0.541, Loss:  1.409
# Epoch   0 Batch  318/1077 - Train Accuracy:  0.459, Validation Accuracy:  0.526, Loss:  1.308
# Epoch   0 Batch  319/1077 - Train Accuracy:  0.495, Validation Accuracy:  0.545, Loss:  1.318
# Epoch   0 Batch  320/1077 - Train Accuracy:  0.520, Validation Accuracy:  0.537, Loss:  1.325
# Epoch   0 Batch  321/1077 - Train Accuracy:  0.482, Validation Accuracy:  0.531, Loss:  1.275
# Epoch   0 Batch  322/1077 - Train Accuracy:  0.462, Validation Accuracy:  0.523, Loss:  1.247
# Epoch   0 Batch  323/1077 - Train Accuracy:  0.504, Validation Accuracy:  0.509, Loss:  1.231
# Epoch   0 Batch  324/1077 - Train Accuracy:  0.458, Validation Accuracy:  0.513, Loss:  1.300
# Epoch   0 Batch  325/1077 - Train Accuracy:  0.492, Validation Accuracy:  0.507, Loss:  1.193
# Epoch   0 Batch  326/1077 - Train Accuracy:  0.509, Validation Accuracy:  0.514, Loss:  1.197
# Epoch   0 Batch  327/1077 - Train Accuracy:  0.468, Validation Accuracy:  0.522, Loss:  1.300
# Epoch   0 Batch  328/1077 - Train Accuracy:  0.499, Validation Accuracy:  0.518, Loss:  1.266
# Epoch   0 Batch  329/1077 - Train Accuracy:  0.463, Validation Accuracy:  0.516, Loss:  1.280
# Epoch   0 Batch  330/1077 - Train Accuracy:  0.496, Validation Accuracy:  0.521, Loss:  1.290
# Epoch   0 Batch  331/1077 - Train Accuracy:  0.481, Validation Accuracy:  0.520, Loss:  1.250
# Epoch   0 Batch  332/1077 - Train Accuracy:  0.494, Validation Accuracy:  0.528, Loss:  1.147
# Epoch   0 Batch  333/1077 - Train Accuracy:  0.481, Validation Accuracy:  0.535, Loss:  1.286
# Epoch   0 Batch  334/1077 - Train Accuracy:  0.487, Validation Accuracy:  0.537, Loss:  1.283
# Epoch   0 Batch  335/1077 - Train Accuracy:  0.533, Validation Accuracy:  0.557, Loss:  1.136
# Epoch   0 Batch  336/1077 - Train Accuracy:  0.502, Validation Accuracy:  0.548, Loss:  1.249
# Epoch   0 Batch  337/1077 - Train Accuracy:  0.471, Validation Accuracy:  0.531, Loss:  1.264
# Epoch   0 Batch  338/1077 - Train Accuracy:  0.503, Validation Accuracy:  0.536, Loss:  1.242
# Epoch   0 Batch  339/1077 - Train Accuracy:  0.490, Validation Accuracy:  0.535, Loss:  1.198
# Epoch   0 Batch  340/1077 - Train Accuracy:  0.479, Validation Accuracy:  0.536, Loss:  1.256
# Epoch   0 Batch  341/1077 - Train Accuracy:  0.520, Validation Accuracy:  0.528, Loss:  1.250
# Epoch   0 Batch  342/1077 - Train Accuracy:  0.484, Validation Accuracy:  0.516, Loss:  1.198
# Epoch   0 Batch  343/1077 - Train Accuracy:  0.455, Validation Accuracy:  0.507, Loss:  1.233
# Epoch   0 Batch  344/1077 - Train Accuracy:  0.476, Validation Accuracy:  0.522, Loss:  1.216
# Epoch   0 Batch  345/1077 - Train Accuracy:  0.500, Validation Accuracy:  0.526, Loss:  1.176
# Epoch   0 Batch  346/1077 - Train Accuracy:  0.468, Validation Accuracy:  0.517, Loss:  1.239
# Epoch   0 Batch  347/1077 - Train Accuracy:  0.487, Validation Accuracy:  0.515, Loss:  1.193
# Epoch   0 Batch  348/1077 - Train Accuracy:  0.501, Validation Accuracy:  0.513, Loss:  1.136
# Epoch   0 Batch  349/1077 - Train Accuracy:  0.466, Validation Accuracy:  0.517, Loss:  1.192
# Epoch   0 Batch  350/1077 - Train Accuracy:  0.479, Validation Accuracy:  0.532, Loss:  1.312
# Epoch   0 Batch  351/1077 - Train Accuracy:  0.456, Validation Accuracy:  0.532, Loss:  1.293
# Epoch   0 Batch  352/1077 - Train Accuracy:  0.449, Validation Accuracy:  0.534, Loss:  1.257
# Epoch   0 Batch  353/1077 - Train Accuracy:  0.445, Validation Accuracy:  0.553, Loss:  1.298
# Epoch   0 Batch  354/1077 - Train Accuracy:  0.466, Validation Accuracy:  0.549, Loss:  1.214
# Epoch   0 Batch  355/1077 - Train Accuracy:  0.515, Validation Accuracy:  0.543, Loss:  1.208
# Epoch   0 Batch  356/1077 - Train Accuracy:  0.483, Validation Accuracy:  0.537, Loss:  1.190
# Epoch   0 Batch  357/1077 - Train Accuracy:  0.544, Validation Accuracy:  0.551, Loss:  1.115
# Epoch   0 Batch  358/1077 - Train Accuracy:  0.485, Validation Accuracy:  0.549, Loss:  1.216
# Epoch   0 Batch  359/1077 - Train Accuracy:  0.494, Validation Accuracy:  0.538, Loss:  1.171
# Epoch   0 Batch  360/1077 - Train Accuracy:  0.477, Validation Accuracy:  0.523, Loss:  1.184
# Epoch   0 Batch  361/1077 - Train Accuracy:  0.507, Validation Accuracy:  0.547, Loss:  1.187
# Epoch   0 Batch  362/1077 - Train Accuracy:  0.527, Validation Accuracy:  0.560, Loss:  1.192
# Epoch   0 Batch  363/1077 - Train Accuracy:  0.459, Validation Accuracy:  0.544, Loss:  1.207
# Epoch   0 Batch  364/1077 - Train Accuracy:  0.485, Validation Accuracy:  0.545, Loss:  1.211
# Epoch   0 Batch  365/1077 - Train Accuracy:  0.472, Validation Accuracy:  0.534, Loss:  1.176
# Epoch   0 Batch  366/1077 - Train Accuracy:  0.495, Validation Accuracy:  0.544, Loss:  1.148
# Epoch   0 Batch  367/1077 - Train Accuracy:  0.519, Validation Accuracy:  0.553, Loss:  1.078
# Epoch   0 Batch  368/1077 - Train Accuracy:  0.491, Validation Accuracy:  0.538, Loss:  1.155
# Epoch   0 Batch  369/1077 - Train Accuracy:  0.472, Validation Accuracy:  0.543, Loss:  1.151
# Epoch   0 Batch  370/1077 - Train Accuracy:  0.500, Validation Accuracy:  0.545, Loss:  1.110
# Epoch   0 Batch  371/1077 - Train Accuracy:  0.534, Validation Accuracy:  0.548, Loss:  1.126
# Epoch   0 Batch  372/1077 - Train Accuracy:  0.508, Validation Accuracy:  0.550, Loss:  1.119
# Epoch   0 Batch  373/1077 - Train Accuracy:  0.561, Validation Accuracy:  0.566, Loss:  1.061
# Epoch   0 Batch  374/1077 - Train Accuracy:  0.446, Validation Accuracy:  0.573, Loss:  1.215
# Epoch   0 Batch  375/1077 - Train Accuracy:  0.542, Validation Accuracy:  0.566, Loss:  1.056
# Epoch   0 Batch  376/1077 - Train Accuracy:  0.550, Validation Accuracy:  0.562, Loss:  1.075
# Epoch   0 Batch  377/1077 - Train Accuracy:  0.490, Validation Accuracy:  0.562, Loss:  1.154
# Epoch   0 Batch  378/1077 - Train Accuracy:  0.494, Validation Accuracy:  0.550, Loss:  1.098
# Epoch   0 Batch  379/1077 - Train Accuracy:  0.530, Validation Accuracy:  0.555, Loss:  1.150
# Epoch   0 Batch  380/1077 - Train Accuracy:  0.484, Validation Accuracy:  0.549, Loss:  1.106
# Epoch   0 Batch  381/1077 - Train Accuracy:  0.503, Validation Accuracy:  0.548, Loss:  1.157
# Epoch   0 Batch  382/1077 - Train Accuracy:  0.505, Validation Accuracy:  0.539, Loss:  1.166
# Epoch   0 Batch  383/1077 - Train Accuracy:  0.540, Validation Accuracy:  0.538, Loss:  1.078
# Epoch   0 Batch  384/1077 - Train Accuracy:  0.471, Validation Accuracy:  0.554, Loss:  1.119
# Epoch   0 Batch  385/1077 - Train Accuracy:  0.480, Validation Accuracy:  0.551, Loss:  1.153
# Epoch   0 Batch  386/1077 - Train Accuracy:  0.499, Validation Accuracy:  0.551, Loss:  1.100
# Epoch   0 Batch  387/1077 - Train Accuracy:  0.545, Validation Accuracy:  0.566, Loss:  1.074
# Epoch   0 Batch  388/1077 - Train Accuracy:  0.526, Validation Accuracy:  0.565, Loss:  1.075
# Epoch   0 Batch  389/1077 - Train Accuracy:  0.525, Validation Accuracy:  0.557, Loss:  1.092
# Epoch   0 Batch  390/1077 - Train Accuracy:  0.484, Validation Accuracy:  0.556, Loss:  1.163
# Epoch   0 Batch  391/1077 - Train Accuracy:  0.522, Validation Accuracy:  0.572, Loss:  1.063
# Epoch   0 Batch  392/1077 - Train Accuracy:  0.478, Validation Accuracy:  0.565, Loss:  1.113
# Epoch   0 Batch  393/1077 - Train Accuracy:  0.525, Validation Accuracy:  0.560, Loss:  1.043
# Epoch   0 Batch  394/1077 - Train Accuracy:  0.461, Validation Accuracy:  0.556, Loss:  1.141
# Epoch   0 Batch  395/1077 - Train Accuracy:  0.520, Validation Accuracy:  0.555, Loss:  1.050
# Epoch   0 Batch  396/1077 - Train Accuracy:  0.500, Validation Accuracy:  0.544, Loss:  1.104
# Epoch   0 Batch  397/1077 - Train Accuracy:  0.563, Validation Accuracy:  0.564, Loss:  1.029
# Epoch   0 Batch  398/1077 - Train Accuracy:  0.505, Validation Accuracy:  0.559, Loss:  1.151
# Epoch   0 Batch  399/1077 - Train Accuracy:  0.426, Validation Accuracy:  0.567, Loss:  1.224
# Epoch   0 Batch  400/1077 - Train Accuracy:  0.516, Validation Accuracy:  0.576, Loss:  1.116
# Epoch   0 Batch  401/1077 - Train Accuracy:  0.508, Validation Accuracy:  0.550, Loss:  1.106
# Epoch   0 Batch  402/1077 - Train Accuracy:  0.532, Validation Accuracy:  0.542, Loss:  1.069
# Epoch   0 Batch  403/1077 - Train Accuracy:  0.492, Validation Accuracy:  0.553, Loss:  1.107
# Epoch   0 Batch  404/1077 - Train Accuracy:  0.553, Validation Accuracy:  0.561, Loss:  1.003
# Epoch   0 Batch  405/1077 - Train Accuracy:  0.484, Validation Accuracy:  0.564, Loss:  1.118
# Epoch   0 Batch  406/1077 - Train Accuracy:  0.523, Validation Accuracy:  0.572, Loss:  1.088
# Epoch   0 Batch  407/1077 - Train Accuracy:  0.496, Validation Accuracy:  0.543, Loss:  1.122
# Epoch   0 Batch  408/1077 - Train Accuracy:  0.505, Validation Accuracy:  0.538, Loss:  1.078
# Epoch   0 Batch  409/1077 - Train Accuracy:  0.478, Validation Accuracy:  0.561, Loss:  1.086
# Epoch   0 Batch  410/1077 - Train Accuracy:  0.457, Validation Accuracy:  0.556, Loss:  1.102
# Epoch   0 Batch  411/1077 - Train Accuracy:  0.523, Validation Accuracy:  0.542, Loss:  1.040
# Epoch   0 Batch  412/1077 - Train Accuracy:  0.514, Validation Accuracy:  0.555, Loss:  1.020
# Epoch   0 Batch  413/1077 - Train Accuracy:  0.522, Validation Accuracy:  0.550, Loss:  1.034
# Epoch   0 Batch  414/1077 - Train Accuracy:  0.480, Validation Accuracy:  0.547, Loss:  1.077
# Epoch   0 Batch  415/1077 - Train Accuracy:  0.535, Validation Accuracy:  0.554, Loss:  1.014
# Epoch   0 Batch  416/1077 - Train Accuracy:  0.496, Validation Accuracy:  0.558, Loss:  1.044
# Epoch   0 Batch  417/1077 - Train Accuracy:  0.502, Validation Accuracy:  0.561, Loss:  1.090
# Epoch   0 Batch  418/1077 - Train Accuracy:  0.486, Validation Accuracy:  0.552, Loss:  1.026
# Epoch   0 Batch  419/1077 - Train Accuracy:  0.502, Validation Accuracy:  0.559, Loss:  1.051
# Epoch   0 Batch  420/1077 - Train Accuracy:  0.489, Validation Accuracy:  0.562, Loss:  1.043
# Epoch   0 Batch  421/1077 - Train Accuracy:  0.493, Validation Accuracy:  0.568, Loss:  1.059
# Epoch   0 Batch  422/1077 - Train Accuracy:  0.503, Validation Accuracy:  0.576, Loss:  1.003
# Epoch   0 Batch  423/1077 - Train Accuracy:  0.532, Validation Accuracy:  0.573, Loss:  1.066
# Epoch   0 Batch  424/1077 - Train Accuracy:  0.475, Validation Accuracy:  0.564, Loss:  1.052
# Epoch   0 Batch  425/1077 - Train Accuracy:  0.542, Validation Accuracy:  0.565, Loss:  0.997
# Epoch   0 Batch  426/1077 - Train Accuracy:  0.523, Validation Accuracy:  0.563, Loss:  1.060
# Epoch   0 Batch  427/1077 - Train Accuracy:  0.494, Validation Accuracy:  0.574, Loss:  1.033
# Epoch   0 Batch  428/1077 - Train Accuracy:  0.551, Validation Accuracy:  0.567, Loss:  0.981
# Epoch   0 Batch  429/1077 - Train Accuracy:  0.528, Validation Accuracy:  0.556, Loss:  1.000
# Epoch   0 Batch  430/1077 - Train Accuracy:  0.502, Validation Accuracy:  0.550, Loss:  1.014
# Epoch   0 Batch  431/1077 - Train Accuracy:  0.486, Validation Accuracy:  0.553, Loss:  1.022
# Epoch   0 Batch  432/1077 - Train Accuracy:  0.518, Validation Accuracy:  0.552, Loss:  1.039
# Epoch   0 Batch  433/1077 - Train Accuracy:  0.498, Validation Accuracy:  0.550, Loss:  1.022
# Epoch   0 Batch  434/1077 - Train Accuracy:  0.468, Validation Accuracy:  0.545, Loss:  1.016
# Epoch   0 Batch  435/1077 - Train Accuracy:  0.543, Validation Accuracy:  0.555, Loss:  1.075
# Epoch   0 Batch  436/1077 - Train Accuracy:  0.525, Validation Accuracy:  0.559, Loss:  0.972
# Epoch   0 Batch  437/1077 - Train Accuracy:  0.484, Validation Accuracy:  0.555, Loss:  1.005
# Epoch   0 Batch  438/1077 - Train Accuracy:  0.530, Validation Accuracy:  0.556, Loss:  0.972
# Epoch   0 Batch  439/1077 - Train Accuracy:  0.519, Validation Accuracy:  0.560, Loss:  1.032
# Epoch   0 Batch  440/1077 - Train Accuracy:  0.524, Validation Accuracy:  0.560, Loss:  1.051
# Epoch   0 Batch  441/1077 - Train Accuracy:  0.477, Validation Accuracy:  0.559, Loss:  1.005
# Epoch   0 Batch  442/1077 - Train Accuracy:  0.488, Validation Accuracy:  0.554, Loss:  0.986
# Epoch   0 Batch  443/1077 - Train Accuracy:  0.530, Validation Accuracy:  0.550, Loss:  0.936
# Epoch   0 Batch  444/1077 - Train Accuracy:  0.489, Validation Accuracy:  0.552, Loss:  1.019
# Epoch   0 Batch  445/1077 - Train Accuracy:  0.461, Validation Accuracy:  0.542, Loss:  1.066
# Epoch   0 Batch  446/1077 - Train Accuracy:  0.501, Validation Accuracy:  0.539, Loss:  0.895
# Epoch   0 Batch  447/1077 - Train Accuracy:  0.492, Validation Accuracy:  0.537, Loss:  1.011
# Epoch   0 Batch  448/1077 - Train Accuracy:  0.511, Validation Accuracy:  0.544, Loss:  1.018
# Epoch   0 Batch  449/1077 - Train Accuracy:  0.471, Validation Accuracy:  0.543, Loss:  1.048
# Epoch   0 Batch  450/1077 - Train Accuracy:  0.486, Validation Accuracy:  0.534, Loss:  0.992
# Epoch   0 Batch  451/1077 - Train Accuracy:  0.528, Validation Accuracy:  0.531, Loss:  0.956
# Epoch   0 Batch  452/1077 - Train Accuracy:  0.496, Validation Accuracy:  0.535, Loss:  0.976
# Epoch   0 Batch  453/1077 - Train Accuracy:  0.509, Validation Accuracy:  0.540, Loss:  0.939
# Epoch   0 Batch  454/1077 - Train Accuracy:  0.543, Validation Accuracy:  0.542, Loss:  0.976
# Epoch   0 Batch  455/1077 - Train Accuracy:  0.549, Validation Accuracy:  0.553, Loss:  0.905
# Epoch   0 Batch  456/1077 - Train Accuracy:  0.526, Validation Accuracy:  0.556, Loss:  0.982
# Epoch   0 Batch  457/1077 - Train Accuracy:  0.506, Validation Accuracy:  0.551, Loss:  0.922
# Epoch   0 Batch  458/1077 - Train Accuracy:  0.456, Validation Accuracy:  0.543, Loss:  0.967
# Epoch   0 Batch  459/1077 - Train Accuracy:  0.520, Validation Accuracy:  0.542, Loss:  0.936
# Epoch   0 Batch  460/1077 - Train Accuracy:  0.489, Validation Accuracy:  0.553, Loss:  0.982
# Epoch   0 Batch  461/1077 - Train Accuracy:  0.515, Validation Accuracy:  0.556, Loss:  0.971
# Epoch   0 Batch  462/1077 - Train Accuracy:  0.500, Validation Accuracy:  0.560, Loss:  0.939
# Epoch   0 Batch  463/1077 - Train Accuracy:  0.494, Validation Accuracy:  0.561, Loss:  0.979
# Epoch   0 Batch  464/1077 - Train Accuracy:  0.542, Validation Accuracy:  0.559, Loss:  0.914
# Epoch   0 Batch  465/1077 - Train Accuracy:  0.493, Validation Accuracy:  0.559, Loss:  1.017
# Epoch   0 Batch  466/1077 - Train Accuracy:  0.518, Validation Accuracy:  0.561, Loss:  0.918
# Epoch   0 Batch  467/1077 - Train Accuracy:  0.574, Validation Accuracy:  0.551, Loss:  0.902
# Epoch   0 Batch  468/1077 - Train Accuracy:  0.527, Validation Accuracy:  0.549, Loss:  0.955
# Epoch   0 Batch  469/1077 - Train Accuracy:  0.494, Validation Accuracy:  0.562, Loss:  0.956
# Epoch   0 Batch  470/1077 - Train Accuracy:  0.497, Validation Accuracy:  0.563, Loss:  0.982
# Epoch   0 Batch  471/1077 - Train Accuracy:  0.503, Validation Accuracy:  0.566, Loss:  0.897
# Epoch   0 Batch  472/1077 - Train Accuracy:  0.517, Validation Accuracy:  0.573, Loss:  0.935
# Epoch   0 Batch  473/1077 - Train Accuracy:  0.511, Validation Accuracy:  0.581, Loss:  0.958
# Epoch   0 Batch  474/1077 - Train Accuracy:  0.533, Validation Accuracy:  0.585, Loss:  0.951
# Epoch   0 Batch  475/1077 - Train Accuracy:  0.518, Validation Accuracy:  0.578, Loss:  0.898
# Epoch   0 Batch  476/1077 - Train Accuracy:  0.486, Validation Accuracy:  0.574, Loss:  0.963
# Epoch   0 Batch  477/1077 - Train Accuracy:  0.563, Validation Accuracy:  0.578, Loss:  0.879
# Epoch   0 Batch  478/1077 - Train Accuracy:  0.516, Validation Accuracy:  0.566, Loss:  0.991
# Epoch   0 Batch  479/1077 - Train Accuracy:  0.518, Validation Accuracy:  0.564, Loss:  0.995
# Epoch   0 Batch  480/1077 - Train Accuracy:  0.506, Validation Accuracy:  0.566, Loss:  0.948
# Epoch   0 Batch  481/1077 - Train Accuracy:  0.505, Validation Accuracy:  0.567, Loss:  0.943
# Epoch   0 Batch  482/1077 - Train Accuracy:  0.526, Validation Accuracy:  0.564, Loss:  1.015
# Epoch   0 Batch  483/1077 - Train Accuracy:  0.502, Validation Accuracy:  0.550, Loss:  0.931
# Epoch   0 Batch  484/1077 - Train Accuracy:  0.521, Validation Accuracy:  0.545, Loss:  0.928
# Epoch   0 Batch  485/1077 - Train Accuracy:  0.555, Validation Accuracy:  0.565, Loss:  0.910
# Epoch   0 Batch  486/1077 - Train Accuracy:  0.516, Validation Accuracy:  0.574, Loss:  0.950
# Epoch   0 Batch  487/1077 - Train Accuracy:  0.498, Validation Accuracy:  0.573, Loss:  0.948
# Epoch   0 Batch  488/1077 - Train Accuracy:  0.502, Validation Accuracy:  0.574, Loss:  0.950
# Epoch   0 Batch  489/1077 - Train Accuracy:  0.547, Validation Accuracy:  0.576, Loss:  0.875
# Epoch   0 Batch  490/1077 - Train Accuracy:  0.520, Validation Accuracy:  0.580, Loss:  0.928
# Epoch   0 Batch  491/1077 - Train Accuracy:  0.549, Validation Accuracy:  0.570, Loss:  0.917
# Epoch   0 Batch  492/1077 - Train Accuracy:  0.502, Validation Accuracy:  0.572, Loss:  0.960
# Epoch   0 Batch  493/1077 - Train Accuracy:  0.542, Validation Accuracy:  0.576, Loss:  0.862
# Epoch   0 Batch  494/1077 - Train Accuracy:  0.533, Validation Accuracy:  0.578, Loss:  0.870
# Epoch   0 Batch  495/1077 - Train Accuracy:  0.545, Validation Accuracy:  0.582, Loss:  0.900
# Epoch   0 Batch  496/1077 - Train Accuracy:  0.504, Validation Accuracy:  0.581, Loss:  0.930
# Epoch   0 Batch  497/1077 - Train Accuracy:  0.475, Validation Accuracy:  0.578, Loss:  0.969
# Epoch   0 Batch  498/1077 - Train Accuracy:  0.584, Validation Accuracy:  0.576, Loss:  0.884
# Epoch   0 Batch  499/1077 - Train Accuracy:  0.536, Validation Accuracy:  0.575, Loss:  0.846
# Epoch   0 Batch  500/1077 - Train Accuracy:  0.557, Validation Accuracy:  0.577, Loss:  0.907
# Epoch   0 Batch  501/1077 - Train Accuracy:  0.514, Validation Accuracy:  0.569, Loss:  0.886
# Epoch   0 Batch  502/1077 - Train Accuracy:  0.530, Validation Accuracy:  0.569, Loss:  0.879
# Epoch   0 Batch  503/1077 - Train Accuracy:  0.534, Validation Accuracy:  0.571, Loss:  0.901
# Epoch   0 Batch  504/1077 - Train Accuracy:  0.527, Validation Accuracy:  0.577, Loss:  0.907
# Epoch   0 Batch  505/1077 - Train Accuracy:  0.572, Validation Accuracy:  0.577, Loss:  0.820
# Epoch   0 Batch  506/1077 - Train Accuracy:  0.494, Validation Accuracy:  0.572, Loss:  0.899
# Epoch   0 Batch  507/1077 - Train Accuracy:  0.526, Validation Accuracy:  0.559, Loss:  0.882
# Epoch   0 Batch  508/1077 - Train Accuracy:  0.563, Validation Accuracy:  0.577, Loss:  0.844
# Epoch   0 Batch  509/1077 - Train Accuracy:  0.536, Validation Accuracy:  0.580, Loss:  0.904
# ...
# Epoch   1 Batch  224/1077 - Train Accuracy:  0.641, Validation Accuracy:  0.655, Loss:  0.506
# Epoch   1 Batch  225/1077 - Train Accuracy:  0.641, Validation Accuracy:  0.659, Loss:  0.529
# Epoch   1 Batch  226/1077 - Train Accuracy:  0.657, Validation Accuracy:  0.655, Loss:  0.511
# Epoch   1 Batch  227/1077 - Train Accuracy:  0.598, Validation Accuracy:  0.657, Loss:  0.554
# Epoch   1 Batch  228/1077 - Train Accuracy:  0.680, Validation Accuracy:  0.660, Loss:  0.495
# Epoch   1 Batch  229/1077 - Train Accuracy:  0.693, Validation Accuracy:  0.664, Loss:  0.502
# Epoch   1 Batch  230/1077 - Train Accuracy:  0.646, Validation Accuracy:  0.662, Loss:  0.502
# Epoch   1 Batch  231/1077 - Train Accuracy:  0.639, Validation Accuracy:  0.664, Loss:  0.525
# Epoch   1 Batch  232/1077 - Train Accuracy:  0.626, Validation Accuracy:  0.668, Loss:  0.545
# Epoch   1 Batch  233/1077 - Train Accuracy:  0.633, Validation Accuracy:  0.669, Loss:  0.544
# Epoch   1 Batch  234/1077 - Train Accuracy:  0.642, Validation Accuracy:  0.665, Loss:  0.502
# Epoch   1 Batch  235/1077 - Train Accuracy:  0.683, Validation Accuracy:  0.661, Loss:  0.477
# Epoch   1 Batch  236/1077 - Train Accuracy:  0.627, Validation Accuracy:  0.659, Loss:  0.523
# Epoch   1 Batch  237/1077 - Train Accuracy:  0.666, Validation Accuracy:  0.653, Loss:  0.465
# Epoch   1 Batch  238/1077 - Train Accuracy:  0.652, Validation Accuracy:  0.653, Loss:  0.510
# Epoch   1 Batch  239/1077 - Train Accuracy:  0.663, Validation Accuracy:  0.657, Loss:  0.482
# Epoch   1 Batch  240/1077 - Train Accuracy:  0.693, Validation Accuracy:  0.653, Loss:  0.487
# Epoch   1 Batch  241/1077 - Train Accuracy:  0.691, Validation Accuracy:  0.653, Loss:  0.471
# Epoch   1 Batch  242/1077 - Train Accuracy:  0.620, Validation Accuracy:  0.659, Loss:  0.502
# Epoch   1 Batch  243/1077 - Train Accuracy:  0.597, Validation Accuracy:  0.657, Loss:  0.533
# Epoch   1 Batch  244/1077 - Train Accuracy:  0.688, Validation Accuracy:  0.656, Loss:  0.486
# Epoch   1 Batch  245/1077 - Train Accuracy:  0.656, Validation Accuracy:  0.664, Loss:  0.475
# Epoch   1 Batch  246/1077 - Train Accuracy:  0.640, Validation Accuracy:  0.658, Loss:  0.494
# Epoch   1 Batch  247/1077 - Train Accuracy:  0.666, Validation Accuracy:  0.662, Loss:  0.489
# Epoch   1 Batch  248/1077 - Train Accuracy:  0.669, Validation Accuracy:  0.658, Loss:  0.478
# Epoch   1 Batch  249/1077 - Train Accuracy:  0.647, Validation Accuracy:  0.657, Loss:  0.497
# Epoch   1 Batch  250/1077 - Train Accuracy:  0.638, Validation Accuracy:  0.638, Loss:  0.479
# Epoch   1 Batch  251/1077 - Train Accuracy:  0.629, Validation Accuracy:  0.635, Loss:  0.504
# Epoch   1 Batch  252/1077 - Train Accuracy:  0.645, Validation Accuracy:  0.653, Loss:  0.505
# Epoch   1 Batch  253/1077 - Train Accuracy:  0.669, Validation Accuracy:  0.650, Loss:  0.474
# Epoch   1 Batch  254/1077 - Train Accuracy:  0.658, Validation Accuracy:  0.644, Loss:  0.506
# Epoch   1 Batch  255/1077 - Train Accuracy:  0.632, Validation Accuracy:  0.643, Loss:  0.493
# Epoch   1 Batch  256/1077 - Train Accuracy:  0.622, Validation Accuracy:  0.629, Loss:  0.551
# Epoch   1 Batch  257/1077 - Train Accuracy:  0.651, Validation Accuracy:  0.629, Loss:  0.492
# Epoch   1 Batch  258/1077 - Train Accuracy:  0.671, Validation Accuracy:  0.628, Loss:  0.484
# Epoch   1 Batch  259/1077 - Train Accuracy:  0.627, Validation Accuracy:  0.634, Loss:  0.487
# Epoch   1 Batch  260/1077 - Train Accuracy:  0.643, Validation Accuracy:  0.636, Loss:  0.462
# Epoch   1 Batch  261/1077 - Train Accuracy:  0.634, Validation Accuracy:  0.642, Loss:  0.490
# Epoch   1 Batch  262/1077 - Train Accuracy:  0.658, Validation Accuracy:  0.656, Loss:  0.505
# Epoch   1 Batch  263/1077 - Train Accuracy:  0.662, Validation Accuracy:  0.657, Loss:  0.483
# Epoch   1 Batch  264/1077 - Train Accuracy:  0.632, Validation Accuracy:  0.656, Loss:  0.509
# Epoch   1 Batch  265/1077 - Train Accuracy:  0.611, Validation Accuracy:  0.656, Loss:  0.505
# Epoch   1 Batch  266/1077 - Train Accuracy:  0.655, Validation Accuracy:  0.666, Loss:  0.489
# Epoch   1 Batch  267/1077 - Train Accuracy:  0.631, Validation Accuracy:  0.656, Loss:  0.465
# Epoch   1 Batch  268/1077 - Train Accuracy:  0.657, Validation Accuracy:  0.659, Loss:  0.501
# Epoch   1 Batch  269/1077 - Train Accuracy:  0.618, Validation Accuracy:  0.661, Loss:  0.534
# Epoch   1 Batch  270/1077 - Train Accuracy:  0.609, Validation Accuracy:  0.658, Loss:  0.512
# Epoch   1 Batch  271/1077 - Train Accuracy:  0.655, Validation Accuracy:  0.658, Loss:  0.479
# Epoch   1 Batch  272/1077 - Train Accuracy:  0.652, Validation Accuracy:  0.658, Loss:  0.515
# Epoch   1 Batch  273/1077 - Train Accuracy:  0.625, Validation Accuracy:  0.654, Loss:  0.482
# Epoch   1 Batch  274/1077 - Train Accuracy:  0.665, Validation Accuracy:  0.651, Loss:  0.488
# Epoch   1 Batch  275/1077 - Train Accuracy:  0.636, Validation Accuracy:  0.643, Loss:  0.468
# Epoch   1 Batch  276/1077 - Train Accuracy:  0.624, Validation Accuracy:  0.647, Loss:  0.532
# Epoch   1 Batch  277/1077 - Train Accuracy:  0.670, Validation Accuracy:  0.658, Loss:  0.449
# Epoch   1 Batch  278/1077 - Train Accuracy:  0.631, Validation Accuracy:  0.648, Loss:  0.525
# Epoch   1 Batch  279/1077 - Train Accuracy:  0.630, Validation Accuracy:  0.645, Loss:  0.532
# Epoch   1 Batch  280/1077 - Train Accuracy:  0.658, Validation Accuracy:  0.643, Loss:  0.505
# Epoch   1 Batch  281/1077 - Train Accuracy:  0.639, Validation Accuracy:  0.651, Loss:  0.516
# Epoch   1 Batch  282/1077 - Train Accuracy:  0.599, Validation Accuracy:  0.651, Loss:  0.528
# Epoch   1 Batch  283/1077 - Train Accuracy:  0.657, Validation Accuracy:  0.656, Loss:  0.488
# Epoch   1 Batch  284/1077 - Train Accuracy:  0.657, Validation Accuracy:  0.645, Loss:  0.504
# Epoch   1 Batch  285/1077 - Train Accuracy:  0.691, Validation Accuracy:  0.648, Loss:  0.472
# Epoch   1 Batch  286/1077 - Train Accuracy:  0.685, Validation Accuracy:  0.649, Loss:  0.456
# Epoch   1 Batch  287/1077 - Train Accuracy:  0.670, Validation Accuracy:  0.653, Loss:  0.482
# Epoch   1 Batch  288/1077 - Train Accuracy:  0.654, Validation Accuracy:  0.669, Loss:  0.509
# Epoch   1 Batch  289/1077 - Train Accuracy:  0.704, Validation Accuracy:  0.668, Loss:  0.491
# Epoch   1 Batch  290/1077 - Train Accuracy:  0.637, Validation Accuracy:  0.671, Loss:  0.517
# Epoch   1 Batch  291/1077 - Train Accuracy:  0.634, Validation Accuracy:  0.671, Loss:  0.496
# Epoch   1 Batch  292/1077 - Train Accuracy:  0.682, Validation Accuracy:  0.665, Loss:  0.468
# Epoch   1 Batch  293/1077 - Train Accuracy:  0.608, Validation Accuracy:  0.672, Loss:  0.525
# Epoch   1 Batch  294/1077 - Train Accuracy:  0.683, Validation Accuracy:  0.664, Loss:  0.457
# Epoch   1 Batch  295/1077 - Train Accuracy:  0.663, Validation Accuracy:  0.654, Loss:  0.515
# Epoch   1 Batch  296/1077 - Train Accuracy:  0.666, Validation Accuracy:  0.654, Loss:  0.451
# Epoch   1 Batch  297/1077 - Train Accuracy:  0.654, Validation Accuracy:  0.654, Loss:  0.507
# Epoch   1 Batch  298/1077 - Train Accuracy:  0.632, Validation Accuracy:  0.652, Loss:  0.520
# Epoch   1 Batch  299/1077 - Train Accuracy:  0.652, Validation Accuracy:  0.656, Loss:  0.488
# Epoch   1 Batch  300/1077 - Train Accuracy:  0.620, Validation Accuracy:  0.661, Loss:  0.495
# Epoch   1 Batch  301/1077 - Train Accuracy:  0.639, Validation Accuracy:  0.654, Loss:  0.483
# Epoch   1 Batch  302/1077 - Train Accuracy:  0.693, Validation Accuracy:  0.651, Loss:  0.476
# Epoch   1 Batch  303/1077 - Train Accuracy:  0.639, Validation Accuracy:  0.645, Loss:  0.491
# Epoch   1 Batch  304/1077 - Train Accuracy:  0.619, Validation Accuracy:  0.646, Loss:  0.469
# Epoch   1 Batch  305/1077 - Train Accuracy:  0.677, Validation Accuracy:  0.654, Loss:  0.473
# Epoch   1 Batch  306/1077 - Train Accuracy:  0.669, Validation Accuracy:  0.665, Loss:  0.470
# Epoch   1 Batch  307/1077 - Train Accuracy:  0.642, Validation Accuracy:  0.658, Loss:  0.473
# Epoch   1 Batch  308/1077 - Train Accuracy:  0.616, Validation Accuracy:  0.646, Loss:  0.512
# Epoch   1 Batch  309/1077 - Train Accuracy:  0.681, Validation Accuracy:  0.659, Loss:  0.442
# Epoch   1 Batch  310/1077 - Train Accuracy:  0.650, Validation Accuracy:  0.661, Loss:  0.499
# Epoch   1 Batch  311/1077 - Train Accuracy:  0.704, Validation Accuracy:  0.658, Loss:  0.454
# Epoch   1 Batch  312/1077 - Train Accuracy:  0.676, Validation Accuracy:  0.662, Loss:  0.505
# Epoch   1 Batch  313/1077 - Train Accuracy:  0.655, Validation Accuracy:  0.658, Loss:  0.460
# Epoch   1 Batch  314/1077 - Train Accuracy:  0.682, Validation Accuracy:  0.659, Loss:  0.484
# Epoch   1 Batch  315/1077 - Train Accuracy:  0.689, Validation Accuracy:  0.667, Loss:  0.444
# Epoch   1 Batch  316/1077 - Train Accuracy:  0.656, Validation Accuracy:  0.664, Loss:  0.452
# Epoch   1 Batch  317/1077 - Train Accuracy:  0.675, Validation Accuracy:  0.664, Loss:  0.508
# Epoch   1 Batch  318/1077 - Train Accuracy:  0.646, Validation Accuracy:  0.666, Loss:  0.494
# Epoch   1 Batch  319/1077 - Train Accuracy:  0.661, Validation Accuracy:  0.661, Loss:  0.490
# Epoch   1 Batch  320/1077 - Train Accuracy:  0.675, Validation Accuracy:  0.660, Loss:  0.474
# Epoch   1 Batch  321/1077 - Train Accuracy:  0.666, Validation Accuracy:  0.656, Loss:  0.475
# Epoch   1 Batch  322/1077 - Train Accuracy:  0.636, Validation Accuracy:  0.659, Loss:  0.459
# Epoch   1 Batch  323/1077 - Train Accuracy:  0.665, Validation Accuracy:  0.656, Loss:  0.482
# Epoch   1 Batch  324/1077 - Train Accuracy:  0.671, Validation Accuracy:  0.647, Loss:  0.471
# Epoch   1 Batch  325/1077 - Train Accuracy:  0.699, Validation Accuracy:  0.648, Loss:  0.465
# Epoch   1 Batch  326/1077 - Train Accuracy:  0.667, Validation Accuracy:  0.653, Loss:  0.461
# Epoch   1 Batch  327/1077 - Train Accuracy:  0.637, Validation Accuracy:  0.653, Loss:  0.504
# Epoch   1 Batch  328/1077 - Train Accuracy:  0.669, Validation Accuracy:  0.648, Loss:  0.489
# Epoch   1 Batch  329/1077 - Train Accuracy:  0.634, Validation Accuracy:  0.655, Loss:  0.493
# Epoch   1 Batch  330/1077 - Train Accuracy:  0.684, Validation Accuracy:  0.652, Loss:  0.472
# Epoch   1 Batch  331/1077 - Train Accuracy:  0.649, Validation Accuracy:  0.651, Loss:  0.489
# Epoch   1 Batch  332/1077 - Train Accuracy:  0.647, Validation Accuracy:  0.656, Loss:  0.430
# Epoch   1 Batch  333/1077 - Train Accuracy:  0.702, Validation Accuracy:  0.655, Loss:  0.485
# Epoch   1 Batch  334/1077 - Train Accuracy:  0.664, Validation Accuracy:  0.654, Loss:  0.471
# Epoch   1 Batch  335/1077 - Train Accuracy:  0.694, Validation Accuracy:  0.654, Loss:  0.446
# Epoch   1 Batch  336/1077 - Train Accuracy:  0.662, Validation Accuracy:  0.651, Loss:  0.501
# Epoch   1 Batch  337/1077 - Train Accuracy:  0.639, Validation Accuracy:  0.660, Loss:  0.498
# Epoch   1 Batch  338/1077 - Train Accuracy:  0.677, Validation Accuracy:  0.662, Loss:  0.500
# Epoch   1 Batch  339/1077 - Train Accuracy:  0.673, Validation Accuracy:  0.661, Loss:  0.465
# Epoch   1 Batch  340/1077 - Train Accuracy:  0.663, Validation Accuracy:  0.667, Loss:  0.478
# Epoch   1 Batch  341/1077 - Train Accuracy:  0.697, Validation Accuracy:  0.667, Loss:  0.510
# Epoch   1 Batch  342/1077 - Train Accuracy:  0.677, Validation Accuracy:  0.665, Loss:  0.446
# Epoch   1 Batch  343/1077 - Train Accuracy:  0.672, Validation Accuracy:  0.670, Loss:  0.480
# Epoch   1 Batch  344/1077 - Train Accuracy:  0.697, Validation Accuracy:  0.668, Loss:  0.474
# Epoch   1 Batch  345/1077 - Train Accuracy:  0.690, Validation Accuracy:  0.663, Loss:  0.454
# Epoch   1 Batch  346/1077 - Train Accuracy:  0.655, Validation Accuracy:  0.669, Loss:  0.484
# Epoch   1 Batch  347/1077 - Train Accuracy:  0.666, Validation Accuracy:  0.666, Loss:  0.445
# Epoch   1 Batch  348/1077 - Train Accuracy:  0.640, Validation Accuracy:  0.662, Loss:  0.453
# Epoch   1 Batch  349/1077 - Train Accuracy:  0.641, Validation Accuracy:  0.669, Loss:  0.454
# Epoch   1 Batch  350/1077 - Train Accuracy:  0.654, Validation Accuracy:  0.678, Loss:  0.471
# Epoch   1 Batch  351/1077 - Train Accuracy:  0.622, Validation Accuracy:  0.668, Loss:  0.480
# Epoch   1 Batch  352/1077 - Train Accuracy:  0.629, Validation Accuracy:  0.656, Loss:  0.472
# Epoch   1 Batch  353/1077 - Train Accuracy:  0.664, Validation Accuracy:  0.649, Loss:  0.509
# Epoch   1 Batch  354/1077 - Train Accuracy:  0.675, Validation Accuracy:  0.644, Loss:  0.482
# Epoch   1 Batch  355/1077 - Train Accuracy:  0.664, Validation Accuracy:  0.657, Loss:  0.468
# Epoch   1 Batch  356/1077 - Train Accuracy:  0.680, Validation Accuracy:  0.656, Loss:  0.455
# Epoch   1 Batch  357/1077 - Train Accuracy:  0.679, Validation Accuracy:  0.657, Loss:  0.443
# Epoch   1 Batch  358/1077 - Train Accuracy:  0.635, Validation Accuracy:  0.669, Loss:  0.484
# Epoch   1 Batch  359/1077 - Train Accuracy:  0.663, Validation Accuracy:  0.667, Loss:  0.476
# Epoch   1 Batch  360/1077 - Train Accuracy:  0.670, Validation Accuracy:  0.653, Loss:  0.462
# Epoch   1 Batch  361/1077 - Train Accuracy:  0.692, Validation Accuracy:  0.662, Loss:  0.484
# Epoch   1 Batch  362/1077 - Train Accuracy:  0.683, Validation Accuracy:  0.659, Loss:  0.466
# Epoch   1 Batch  363/1077 - Train Accuracy:  0.611, Validation Accuracy:  0.658, Loss:  0.489
# Epoch   1 Batch  364/1077 - Train Accuracy:  0.668, Validation Accuracy:  0.661, Loss:  0.482
# Epoch   1 Batch  365/1077 - Train Accuracy:  0.619, Validation Accuracy:  0.669, Loss:  0.457
# Epoch   1 Batch  366/1077 - Train Accuracy:  0.659, Validation Accuracy:  0.676, Loss:  0.469
# Epoch   1 Batch  367/1077 - Train Accuracy:  0.683, Validation Accuracy:  0.676, Loss:  0.423
# Epoch   1 Batch  368/1077 - Train Accuracy:  0.703, Validation Accuracy:  0.680, Loss:  0.459
# Epoch   1 Batch  369/1077 - Train Accuracy:  0.643, Validation Accuracy:  0.673, Loss:  0.443
# Epoch   1 Batch  370/1077 - Train Accuracy:  0.675, Validation Accuracy:  0.671, Loss:  0.444
# Epoch   1 Batch  371/1077 - Train Accuracy:  0.693, Validation Accuracy:  0.663, Loss:  0.449
# Epoch   1 Batch  372/1077 - Train Accuracy:  0.660, Validation Accuracy:  0.655, Loss:  0.447
# Epoch   1 Batch  373/1077 - Train Accuracy:  0.711, Validation Accuracy:  0.657, Loss:  0.433
# Epoch   1 Batch  374/1077 - Train Accuracy:  0.662, Validation Accuracy:  0.658, Loss:  0.480
# Epoch   1 Batch  375/1077 - Train Accuracy:  0.695, Validation Accuracy:  0.655, Loss:  0.433
# Epoch   1 Batch  376/1077 - Train Accuracy:  0.668, Validation Accuracy:  0.654, Loss:  0.454
# Epoch   1 Batch  377/1077 - Train Accuracy:  0.662, Validation Accuracy:  0.665, Loss:  0.474
# Epoch   1 Batch  378/1077 - Train Accuracy:  0.634, Validation Accuracy:  0.670, Loss:  0.447
# Epoch   1 Batch  379/1077 - Train Accuracy:  0.696, Validation Accuracy:  0.667, Loss:  0.466
# Epoch   1 Batch  380/1077 - Train Accuracy:  0.664, Validation Accuracy:  0.665, Loss:  0.442
# Epoch   1 Batch  381/1077 - Train Accuracy:  0.654, Validation Accuracy:  0.663, Loss:  0.477
# Epoch   1 Batch  382/1077 - Train Accuracy:  0.667, Validation Accuracy:  0.659, Loss:  0.487
# Epoch   1 Batch  383/1077 - Train Accuracy:  0.669, Validation Accuracy:  0.659, Loss:  0.451
# Epoch   1 Batch  384/1077 - Train Accuracy:  0.693, Validation Accuracy:  0.666, Loss:  0.444
# Epoch   1 Batch  385/1077 - Train Accuracy:  0.670, Validation Accuracy:  0.671, Loss:  0.466
# Epoch   1 Batch  386/1077 - Train Accuracy:  0.638, Validation Accuracy:  0.671, Loss:  0.452
# Epoch   1 Batch  387/1077 - Train Accuracy:  0.715, Validation Accuracy:  0.670, Loss:  0.443
# Epoch   1 Batch  388/1077 - Train Accuracy:  0.674, Validation Accuracy:  0.674, Loss:  0.459
# Epoch   1 Batch  389/1077 - Train Accuracy:  0.681, Validation Accuracy:  0.670, Loss:  0.452
# Epoch   1 Batch  390/1077 - Train Accuracy:  0.635, Validation Accuracy:  0.673, Loss:  0.480
# Epoch   1 Batch  391/1077 - Train Accuracy:  0.657, Validation Accuracy:  0.674, Loss:  0.458
# Epoch   1 Batch  392/1077 - Train Accuracy:  0.677, Validation Accuracy:  0.676, Loss:  0.430
# Epoch   1 Batch  393/1077 - Train Accuracy:  0.684, Validation Accuracy:  0.673, Loss:  0.427

# %% [markdown]
# ### Save Parameters
# Save the `batch_size` and `save_path` parameters for inference.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Save parameters for checkpoint
helper.save_params(save_path)

# %% [markdown]
# # Checkpoint

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import tensorflow as tf
import numpy as np
import helper
import problem_unittests as tests

_, (source_vocab_to_int, target_vocab_to_int), (source_int_to_vocab, target_int_to_vocab) = helper.load_preprocess()
load_path = helper.load_params()

# %% [markdown]
# ## Sentence to Sequence
# To feed a sentence into the model for translation, you first need to preprocess it.  Implement the function `sentence_to_seq()` to preprocess new sentences.
#
# - Convert the sentence to lowercase
# - Convert words into ids using `vocab_to_int`
#  - Convert words not in the vocabulary, to the `<UNK>` word id.

# %%
def sentence_to_seq(sentence, vocab_to_int):
    """
    Convert a sentence to a sequence of ids
    :param sentence: String
    :param vocab_to_int: Dictionary to go from the words to an id
    :return: List of word ids
    """
    # TODO: Implement Function
    return None


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_sentence_to_seq(sentence_to_seq)

# %% [markdown]
# ## Translate
# This will translate `translate_sentence` from English to French.

# %%
translate_sentence = 'he saw a old yellow truck .'


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
translate_sentence = sentence_to_seq(translate_sentence, source_vocab_to_int)

loaded_graph = tf.Graph()
with tf.Session(graph=loaded_graph) as sess:
    # Load saved model
    loader = tf.train.import_meta_graph(load_path + '.meta')
    loader.restore(sess, load_path)

    input_data = loaded_graph.get_tensor_by_name('input:0')
    logits = loaded_graph.get_tensor_by_name('logits:0')
    keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')

    translate_logits = sess.run(logits, {input_data: [translate_sentence], keep_prob: 1.0})[0]

print('Input')
print('  Word Ids:      {}'.format([i for i in translate_sentence]))
print('  English Words: {}'.format([source_int_to_vocab[i] for i in translate_sentence]))

print('\nPrediction')
print('  Word Ids:      {}'.format([i for i in np.argmax(translate_logits, 1)]))
print('  French Words: {}'.format([target_int_to_vocab[i] for i in np.argmax(translate_logits, 1)]))

# %% [markdown]
# ## Imperfect Translation
# You might notice that some sentences translate better than others.  Since the dataset you're using only has a vocabulary of 227 English words of the thousands that you use, you're only going to see good results using these words.  For this project, you don't need a perfect translation. However, if you want to create a better translation model, you'll need better data.
#
# You can train on the [WMT10 French-English corpus](http://www.statmt.org/wmt10/training-giga-fren.tar).  This dataset has more vocabulary and richer in topics discussed.  However, this will take you days to train, so make sure you've a GPU and the neural network is performing well on dataset we provided.  Just make sure you play with the WMT10 corpus after you've submitted this project.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_language_translation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "helper.py" and "problem_unittests.py" files in your submission.
